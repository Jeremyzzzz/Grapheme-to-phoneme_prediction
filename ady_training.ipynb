# %% [markdown]
# ### Note: Model is trained on Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import unicodedata
import string
import re
import random
import time
import datetime
import math

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
import torchtext

import spacy
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read data

# %%
data_path = "/content/drive/MyDrive/g2p/data_new/ady/"
root_path = "/content/drive/MyDrive/g2p/"

# %%
df_ady_train = pd.read_csv(data_path + "ady_train.tsv", sep='\t', header=None, encoding='utf-8').rename(columns={0:"grapheme", 1:"phoneme"})
df_ady_dev = pd.read_csv(data_path + "ady_dev.tsv", sep='\t', header=None, encoding='utf-8').rename(columns={0:"grapheme", 1:"phoneme"})

# %%
df_ady_train.head()
# Out:
#        grapheme              phoneme
# 0        хъупцӏ          χʷ ə p t͡sʼ
# 1       шъуялъэ        ʃʷ ə j aː ɬ a
# 2  хьалжъогъуан  ħ aː l ʐʷ a ʁʷ aː n
# 3      джаргъэн       d͡ʒ aː r ʁ a n
# 4      кӏэлэгъу         t͡ʃ a l a ʁʷ

# %%
df_ady_dev.head()
# Out:
#      grapheme            phoneme
# 0   шӏуцӏагъэ    ʃʷʼ t͡sʼ aː ʁ a
# 1        хьэо            ħ a w a
# 2      лъэужь          ɬ a w ə ʑ
# 3    бытырбыф    b a t ə r b ə f
# 4  гъэджыджэн  ʁ a d͡ʒ ə d͡ʒ a n

# %%
df_ady_train.shape
# Out:
# (700, 2)

# %%
df_ady_dev.shape
# Out:
# (100, 2)

# %% [markdown]
# ## Use torchtext to prepare data

# %%
def tokenize_grapheme(text):
    """
    Tokenizes French text from a string into a list of strings (tokens)
    """
    return list(text)

# %%
def tokenize_phoneme(text):
    """
    Tokenizes French text from a string into a list of strings (tokens)
    """
    return text.split()

# %%
df_ady_train_gra = df_ady_train["grapheme"].apply(tokenize_grapheme)

df_ady_train_gra
# Out:
# 0                        [х, ъ, у, п, ц, ӏ]
# 1                     [ш, ъ, у, я, л, ъ, э]
# 2      [х, ь, а, л, ж, ъ, о, г, ъ, у, а, н]
# 3                  [д, ж, а, р, г, ъ, э, н]
# 4                  [к, ӏ, э, л, э, г, ъ, у]
#                        ...
# 695                [е, г, ъ, э, з, ы, г, ъ]
# 696                            [п, с, э, и]
# 697             [ж, ъ, о, г, ъ, о, ш, ӏ, у]
# 698    [ӏ, э, к, ӏ, э, г, ъ, э, х, ь, а, н]
# 699                         [т, е, п, х, э]
# Name: grapheme, Length: 700, dtype: object

# %%
df_ady_train_pho = df_ady_train["phoneme"].apply(tokenize_phoneme)

df_ady_train_pho
# Out:
# 0                  [χʷ, ə, p, t͡sʼ]
# 1              [ʃʷ, ə, j, aː, ɬ, a]
# 2      [ħ, aː, l, ʐʷ, a, ʁʷ, aː, n]
# 3             [d͡ʒ, aː, r, ʁ, a, n]
# 4                [t͡ʃ, a, l, a, ʁʷ]
#                    ...
# 695           [j, a, ʁ, a, t, ə, ʁ]
# 696                 [p, s, a, j, ə]
# 697              [ʐʷ, a, ʁʷ, a, ʃʷ]
# 698       [ʔ, ə, t͡ʃʼ, a, ħ, aː, n]
# 699              [t, a, j, p, x, a]
# Name: phoneme, Length: 700, dtype: object

# %%
SRC = torchtext.legacy.data.Field(tokenize = tokenize_grapheme, 
            init_token = '<sos>', # since initial encoder hidden state is always set to zero, the network can figure out that the time step is 0 and this token is optional
            eos_token = '<eow>', 
            lower = True)
TRG = torchtext.legacy.data.Field(tokenize = tokenize_phoneme, 
            init_token = '<sow>', 
            eos_token = '<eow>', 
            lower = True)

# %%
assert SRC.tokenize("hello") == ['h', 'e', 'l', 'l', 'o']
assert TRG.tokenize("b a b ɛ ɬ") == ['b', 'a', 'b', 'ɛ', 'ɬ']

# %%
train, val = torchtext.legacy.data.TabularDataset.splits(
    path=data_path, train='ady_train.tsv',validation='ady_dev.tsv', 
    format='tsv', skip_header=False, fields=[('SRC', SRC), ('TRG', TRG)])

test = torchtext.legacy.data.TabularDataset(
    path=data_path + 'new_ady_test.tsv',
    format='tsv', skip_header=False, fields=[('SRC', SRC), ('TRG', TRG)])

# %%
print(next(iter(train)).TRG)
# Out:
# ['χʷ', 'ə', 'p', 't͡sʼ']

# %%
print(next(iter(train)).SRC)
# Out:
# ['х', 'ъ', 'у', 'п', 'ц', 'ӏ']

# %%
# build vocab
SRC.build_vocab(train)
TRG.build_vocab(train)

# %%
len(SRC.vocab)
# Out:
# 36

# %%
print(SRC.vocab.itos)
# Out:
# ['<unk>', '<pad>', '<sos>', '<eow>', 'э', 'ъ', 'ы', 'н', 'ӏ', 'у', 'г', 'к', 'а', 'х', 'п', 'о', 'ь', 'л', 'ш', 'т', 'д', 'з', 'б', 'ж', 'м', 'р', 'с', 'е', 'ч', 'щ', 'ц', 'ф', 'и', 'й', 'я', 'в']

# %%
print(TRG.vocab.itos)
# Out:
# ['<unk>', '<pad>', '<sow>', '<eow>', 'a', 'ə', 'n', 'aː', 'p', 'b', 't', 'ʁ', 'j', 'w', 'z', 'ħ', 'm', 'r', 'ʁʷ', 'q', 's', 'd', 't͡ʃʼ', 'ɬ', 't͡ʃ', 'x', 'ɕ', 'l', 'd͡ʒ', 'ʂ', 'qʷ', 'ɡʷ', 'f', 'ʔ', 'ʑ', 'χʷ', 'ʃ', 'ʃʼ', 'ʔʷ', 'χ', 'kʷ', 't͡sʼ', 'kʷʼ', 'ʐ', 't͡s', 'd͡z', 'ʒ', 'ʃʷ', 'pʼ', 'tʼ', 'ɣ', 'ʂʷ', 'ʃʷʼ', 't͡ʂʼ', 'kʲʼ', 'ɮ', 'ɬʼ', 't͡ʂ', 'ɡʲ', 'sʼ', 'ʐʷ', 'tʷʼ', 'ʒʷ', 'kʲ', 'd͡zʷ', 'k', 'kʼ', 't͡ʃʷ', 'pʷʼ', 't͡sʷ']

# %%
print(TRG.vocab.stoi['<pad>'])
# Out:
# 1

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
from torchtext.legacy.data import Iterator, BucketIterator
train_iter = BucketIterator(
        train,
        batch_size=1,
        device=device,
        sort_key=len,
        shuffle=True)
dev_iter, test_iter = Iterator.splits(
        (val, test),
        batch_sizes=(1,1),
        device=device,
        sort=False,
        shuffle=False)

# %%
# batch example of training data
for batch in train_iter:
    src = batch.SRC
    trg = batch.TRG
    print('tensor size of source language:', src.shape)
    print('tensor size of target language:', trg.shape)
    print('the tensor of first example in target language:', trg[:,0])
    break
# Out:
# tensor size of source language: torch.Size([9, 1])
# tensor size of target language: torch.Size([10, 1])
# the tensor of first example in target language: tensor([ 2, 36,  4,  8, 20,  4, 13,  5,  6,  3], device='cuda:0')

# %% [markdown]
# ## Build seq2seq+attention model

# %% [markdown]
# ### Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, n_layers, dropout):
        super().__init__()

        self.emb_dim = emb_dim
        self.enc_hid_dim = enc_hid_dim
        self.dropout = dropout
        self.n_layers = n_layers

        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.lstm = nn.LSTM(emb_dim, enc_hid_dim, n_layers, dropout=dropout, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        
        #src = [src len, batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src len, batch size, emb dim]
        
        outputs, (hidden, cell) = self.lstm(embedded)
       
        # outputs are always from the top hidden layer, if bidirectional outputs are concatenated.
        # outputs = [sequence_length, batch_size, hidden_dim * num_directions]
        # hidden = [num_layers * num_directions, batch_size, hidden_size]
        # cell = [num_layers * num_directions, batch_size, hidden_size]

        a, b, c = outputs.shape
        h_a, h_b, h_c = hidden.shape

        return outputs.view(a, b, 2, -1).mean(dim=2), (hidden.view(self.n_layers, 2, h_b, h_c).mean(dim=1).squeeze(0), cell.view(self.n_layers, 2, h_b, h_c).mean(dim=1))

# %% [markdown]
# ### Attention

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        
        self.W_a = nn.Linear(enc_hid_dim + dec_hid_dim, dec_hid_dim)
        self.v_a = nn.Parameter(torch.rand(dec_hid_dim)) # same as doing nn.Linear(dec_hid_dim, 1, bias=False)
        self.neg_inf = torch.tensor(-1e7, device=device)
        
    def forward(self, hidden, encoder_outputs, attention_mask):
        #(decoder) hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim]
        #attention_mask = [batch_size, src_len]
        
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #repeat decoder hidden state src_len-1 times
        # print("attnetion forward encoder outputs: ", encoder_outputs.shape) # 2 x 2 x 512
        # print("attnetion forward hidden: ", hidden.shape) # 2 x 2 x 512
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #hidden = [batch size, src len, dec hid dim]
        #encoder_outputs = [batch size, src len, enc hid dim]
        
        # attention scoring function - part 1 - tanh(W_a[s;h])
        energy = torch.tanh(self.W_a(torch.cat((hidden, encoder_outputs), dim = 2))) 
        
        #energy = [batch size, src len, dec hid dim]
        
        energy = energy.permute(0, 2, 1)
        
        #energy = [batch size, dec hid dim, src len]
        
        #v = [dec hid dim]
        
        v = self.v_a.repeat(batch_size, 1).unsqueeze(1)
        
        #v = [batch size, 1, dec hid dim]
        
        # attention scoring function - part 2 - v_a(tanh(W_a[s;h]))
        attention = torch.bmm(v, energy).squeeze(1)
        
        #attention= [batch size, src len]

        # before computing the softmax, set attention to pad tokens to -infinity
        attention[attention_mask] = self.neg_inf

        # attention scoring function - part 2 - softmax(v_a(tanh(W_a[s;h])))
        return F.softmax(attention, dim=1)

# %% [markdown]
# ### Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, n_layers, dropout, attention):
        super().__init__()
        
        self.output_dim = output_dim
        self.attention = attention
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.LSTM(enc_hid_dim + emb_dim, dec_hid_dim, n_layers, dropout=dropout)
        
        self.fc_out = nn.Linear(enc_hid_dim + dec_hid_dim + emb_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell, encoder_outputs, attention_mask):
             
        #input = [batch size]
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim]
        #attention_mask = [batch_size, src_len]
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
        # get the attention probabilities
        attention_weights = self.attention(hidden, encoder_outputs, attention_mask)
                
        #attention_weights = [batch size, src len]
        
        attention_weights = attention_weights.unsqueeze(1)
        
        #a = [batch size, 1, src len]
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #encoder_outputs = [batch size, src len, enc hid dim]
        # perform weighted sum of encoder hidden states to get attention output
        weighted = torch.bmm(attention_weights, encoder_outputs)
        
        #weighted = [batch size, 1, enc hid dim]
        
        weighted = weighted.permute(1, 0, 2)
        
        #weighted = [1, batch size, enc hid dim]
        # concatenate the attention outputs (or context vectors) with the current decoder input
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        
        #rnn_input = [1, batch size, (enc hid dim) + emb dim]
        output, (hidden, cell) = self.rnn(rnn_input, (hidden.unsqueeze(0), cell))
        
        #output = [seq len, batch size, dec hid dim * n directions]
        #hidden = [n layers * n directions, batch size, dec hid dim]
        
        #seq len, n layers and n directions will always be 1 in this decoder, therefore:
        #output = [1, batch size, dec hid dim]
        #hidden = [1, batch size, dec hid dim]
        #this also means that output == hidden
        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        # classification over the entire word vocabulary
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden.squeeze(0), cell, attention_weights

# %% [markdown]
# ### Seq2seq with attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src len, batch size]
        #trg = [trg len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use teacher forcing 75% of the time
        batch_size = src.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim

        # create encoder attention mask, set attention to pad tokens to -infinity 
        attention_mask = (src == SRC.vocab.stoi[SRC.pad_token]).transpose(0, 1)
        # attention_mask = [batch size, src len]
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        # save the encoder-decoder attention weights
        # all_attention_weights = [batch_size, trg len-1, src len ]
        all_attention_weights = torch.zeros(trg.shape[1], trg.shape[0]-1, src.shape[0])
        #encoder_outputs is all hidden states of the input sequence, back and forwards
        #hidden is the final forward and backward hidden states, passed through a linear layer
        encoder_outputs, (hidden, cell) = self.encoder(src)
                
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        for t in range(1, trg_len):
            
            #insert input token embedding, previous hidden state and all encoder hidden states
            #receive output tensor (predictions) and new hidden state
            output, hidden, cell, attention_weights = self.decoder(input, hidden, cell, encoder_outputs, attention_mask)
            
            # all_attention_weights[t-1] = [src len, batch size]
            all_attention_weights[:,t-1,:] = attention_weights.squeeze(1)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1

        return outputs,all_attention_weights

# %% [markdown]
# ### Train the seq2seq model

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)

# hyperparameters
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
ENC_HID_DIM = 512
DEC_HID_DIM = 512
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5
N_LAYERS = 1
LEARNING_RT = 0.001

# model components
attn = Attention(ENC_HID_DIM, DEC_HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, N_LAYERS, DEC_DROPOUT, attn)
model = Seq2Seq(enc, dec, device).to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
# weight init ## pre-trained embeddings later
def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)
            
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(36, 256)
#     (lstm): LSTM(256, 512, dropout=0.5, bidirectional=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (W_a): Linear(in_features=1024, out_features=512, bias=True)
#     )
#     (embedding): Embedding(70, 256)
#     (rnn): LSTM(768, 512, dropout=0.5)
#     (fc_out): Linear(in_features=1280, out_features=70, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
optimizer = optim.Adam(model.parameters())

# %%
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
print('<pad> token index: ',TRG_PAD_IDX)
## we will ignore the pad token in true target set
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
# Out:
# <pad> token index:  1

# %%
clip = 1
model.train()

for i, batch in enumerate(train_iter):

    src = batch.SRC
    trg = batch.TRG
    optimizer.zero_grad()
    output,_ = model(src, trg)
    #trg = [trg len, batch size]
    #output = [trg len, batch size, output dim]

    output_dim = output.shape[-1]

    output = output[1:].view(-1, output_dim)
    trg = trg[1:].view(-1)

    #trg = [(trg len - 1) * batch size]
    #output = [(trg len - 1) * batch size, output dim]

    loss = criterion(output, trg)

    loss.backward()

    torch.nn.utils.clip_grad_norm_(model.parameters(), clip)

    optimizer.step()

    print(loss/src.shape[1])
    break

    # 2, 2, 512; ==> 1, 2, 1024; <-
# Out:
# tensor(4.2485, device='cuda:0', grad_fn=<DivBackward0>)

# %% [markdown]
# ## Train

# %%
def train_func(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.SRC
        trg = batch.TRG
        
        optimizer.zero_grad()
        
        output,_ = model(src, trg)
        
        #trg = [trg len, batch size]
        #output = [trg len, batch size, output dim]
        
        output_dim = output.shape[-1]
        
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)
        
        #trg = [(trg len - 1) * batch size]
        #output = [(trg len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.SRC
            trg = batch.TRG

            output,_ = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg len, batch size]
            #output = [trg len, batch size, output dim]

            output_dim = output.shape[-1]
            
            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)

            #trg = [(trg len - 1) * batch size]
            #output = [(trg len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 10
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train_func(model, train_iter, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, dev_iter, criterion)
    
    end_time = time.time()
    state_dict_model = model.state_dict() 
    state = {
        'epoch': epoch,
        'state_dict': state_dict_model,
        'optimizer': optimizer.state_dict()
        }
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    torch.save(state, root_path + "models/ady/" +str(epoch+1)+".pt")
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f}')
# Out:
# Epoch: 01 | Time: 0m 11s
# 	Train Loss: 2.853
# 	 Val. Loss: 2.798
# Epoch: 02 | Time: 0m 11s
# 	Train Loss: 2.375
# 	 Val. Loss: 2.434
# Epoch: 03 | Time: 0m 11s
# 	Train Loss: 1.904
# 	 Val. Loss: 1.818
# Epoch: 04 | Time: 0m 11s
# 	Train Loss: 1.261
# 	 Val. Loss: 1.334
# Epoch: 05 | Time: 0m 11s
# 	Train Loss: 0.821
# 	 Val. Loss: 1.079
# Epoch: 06 | Time: 0m 11s
# 	Train Loss: 0.562
# 	 Val. Loss: 0.993
# Epoch: 07 | Time: 0m 11s
# 	Train Loss: 0.383
# 	 Val. Loss: 0.870
# Epoch: 08 | Time: 0m 11s
# 	Train Loss: 0.341
# 	 Val. Loss: 0.839
# Epoch: 09 | Time: 0m 11s
# 	Train Loss: 0.212
# 	 Val. Loss: 1.081
# Epoch: 10 | Time: 0m 11s
# 	Train Loss: 0.197
# 	 Val. Loss: 0.905

# %% [markdown]
# ## Evluation

# %%
def inference(model, dev_iter, src_vocab, trg_vocab, attention = True, max_trg_len = 64):
    '''
    Function for translation inference

    Input: 
    model: translation model;
    trg_vocab: Target torchtext Field
    attention: the model returns attention weights or not.
    max_trg_len: the maximal length of translation text (optinal), default = 64

    Output:
    Corpus BLEU score.
    '''
    from torchtext.legacy.data import TabularDataset
    from torchtext.legacy.data import Iterator

    # convert index to text string
    def convert_itos(convert_vocab, token_ids):
        list_string = []
        for i in token_ids:
            if i == convert_vocab.vocab.stoi['<eos>']:
                break
            else:
                token = convert_vocab.vocab.itos[i]
                list_string.append(token)
        return list_string
  
    model.eval()
    all_trg = []
    all_translated_trg = []

    TRG_PAD_IDX = trg_vocab.vocab.stoi[trg_vocab.pad_token]

    with torch.no_grad():
    
        for i, batch in enumerate(dev_iter):

            src = batch.SRC
            #src = [src len, batch size]

            trg = batch.TRG
            #trg = [trg len, batch size]

            batch_size = trg.shape[1]

            # create a placeholder for traget language with shape of [max_trg_len, batch_size] where all the elements are the index of <pad>. Then send to device
            trg_placeholder = torch.Tensor(max_trg_len, batch_size)
            trg_placeholder.fill_(TRG_PAD_IDX)
            trg_placeholder = trg_placeholder.long().to(device)
            if attention == True:
              output,_ = model(src, trg_placeholder, 0) #turn off teacher forcing
            else:
              output,_ = model(src, trg_placeholder, 0) #turn off teacher forcing
            # get translation results, we ignor first token <sos> in both translation and target sentences. 
            # output_translate = [(trg len - 1), batch, output dim] output dim is size of target vocabulary.
            output_translate = output[1:]
            # store gold target sentences to a list 
            all_trg.append(trg[1:].cpu())

            # Choose top 1 word from decoder's output, we get the probability and index of the word
            prob, token_id = output_translate.data.topk(1)
            translation_token_id = token_id.squeeze(2).cpu()

            # store gold target sentences to a list 
            all_translated_trg.append(translation_token_id)
      
    all_gold_text = []
    all_translated_text = []
    for i in range(len(all_trg)): 
        cur_gold = all_trg[i]
        cur_translation = all_translated_trg[i]
        for j in range(cur_gold.shape[1]):
            gold_convered_strings = convert_itos(trg_vocab,cur_gold[:,j])
            trans_convered_strings = convert_itos(trg_vocab,cur_translation[:,j])

            all_gold_text.append(gold_convered_strings)
            all_translated_text.append(trans_convered_strings)

    return all_gold_text, all_translated_text

# %%
def get_validation_score(model_best, dev_iter, src_vocab, trg_vocab, out_fp):
  gold, translated = inference(model_best, dev_iter, src_vocab, trg_vocab, True, 64)
  processed_gold = []
  for word in gold:
    curr_word = []
    for char in word:
      if char != "<eow>" and char != "<pad>":
        curr_word.append(char)
    processed_gold.append(curr_word)
  processed_translated = []
  for word in translated:
    curr_word = []
    for char in word:
      if char == "<eow>":
        break
      if char != "<eow>":
        curr_word.append(char)
    processed_translated.append(curr_word)
  with open(out_fp, "w", encoding="utf-8") as fout:
    for g, t in zip(processed_gold, processed_translated):
      fout.write(" ".join(g) + "\t" + " ".join(t) + "\n")

# %%
# %cd /content/drive/MyDrive/g2p
# Out:
# /content/drive/MyDrive/g2p

# %%
for i in range(1, 11):
  print("epoch:", i)
  checkpoint = torch.load(root_path+f"models/ady/{i}.pt")
  model.load_state_dict(checkpoint['state_dict'])
  get_validation_score(model, dev_iter, SRC, TRG, root_path+"evaluation/ady_gold_translated.tsv")
  # !python evaluate.py /content/drive/MyDrive/g2p/evaluation/ady_gold_translated.tsv
# Out:
# epoch: 1
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'q aː aː aː aː aː')
# WARNING: Incorrect prediction:	'ħ a w a' (predicted: 'b a a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'b ə aː a')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə r ə r ə n')
# WARNING: Incorrect prediction:	'ʁ a d͡ʒ ə d͡ʒ a n' (predicted: 'j a a a a a a n')
# WARNING: Incorrect prediction:	'ʔʷ a f ə n t͡ʂ a' (predicted: 'b ə p ə ə a')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'n ə n ə n a n')
# WARNING: Incorrect prediction:	'p χ a n tʼ a kʷʼ' (predicted: 'b a a a a a a a')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 'b ə p ə n')
# WARNING: Incorrect prediction:	'w a r ə' (predicted: 'j ə n')
# WARNING: Incorrect prediction:	'p aː p t͡ʃʼ a' (predicted: 'b a a a a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'q aː aː aː aː aː aː aː')
# WARNING: Incorrect prediction:	'ʃ ə p χʷ' (predicted: 'b ə aː a')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'q aː aː aː aː aː a')
# WARNING: Incorrect prediction:	'ʃʷʼ a ʔʷ ə n' (predicted: 'j a a a n')
# WARNING: Incorrect prediction:	'qʷ a z ə n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'χ aː ʁ a' (predicted: 'p a aː a a')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 'q aː aː aː a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'n ə n ə n ə n a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'b a a a a a a')
# WARNING: Incorrect prediction:	'z a ʁ a n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'q a a a a a a')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'b a aː a a')
# WARNING: Incorrect prediction:	'd a f a n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'b ə n ə n ə')
# WARNING: Incorrect prediction:	'd ə w' (predicted: 'b ə n')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'b ə r ə n ə')
# WARNING: Incorrect prediction:	'q a ʁ a ɬ a ʁʷ a n ə' (predicted: 'j ə n ə n ə n ə n')
# WARNING: Incorrect prediction:	'b z aː d͡ʒ a' (predicted: 'b a a a a')
# WARNING: Incorrect prediction:	'ʁ a p t͡sʼ aː kʷʼ a' (predicted: 'b aː aː aː aː aː a')
# WARNING: Incorrect prediction:	'ʁ a t͡ʃʼ ə n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'b aː aː aː aː aː')
# WARNING: Incorrect prediction:	'ɕ ə w aː n' (predicted: 'b ə n ə n')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'n ə n ə n a n')
# WARNING: Incorrect prediction:	'b ʁʷ a t a n' (predicted: 'n ə n ə n a n')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'b aː aː aː aː')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'q aː aː aː aː aː aː aː')
# WARNING: Incorrect prediction:	'b l a w ə n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'ʐʷ a t ə n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	't͡ʃ a m ə' (predicted: 'b a a')
# WARNING: Incorrect prediction:	'ħ aː b l ə w' (predicted: 'b a a a a')
# WARNING: Incorrect prediction:	'd aː d ə w' (predicted: 'b a a a')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'b a a a a a a')
# WARNING: Incorrect prediction:	'ɬ ə kʷʼ a ʂ a n' (predicted: 'j a a a a a a n')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'j ə n ə n ə n a n')
# WARNING: Incorrect prediction:	'ʃ ə b z ə' (predicted: 'b ə n ə n')
# WARNING: Incorrect prediction:	'b z a ɡʷ ə ħ' (predicted: 'b ə p ə n')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'b a a a a a a a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'n ə n ə n ə n')
# WARNING: Incorrect prediction:	'ɡʷ ə m ə ʔʷ' (predicted: 'b ə p ə')
# WARNING: Incorrect prediction:	'q a b ə' (predicted: 'b a a a')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'n a n')
# WARNING: Incorrect prediction:	'p ʂ a b ə d a ɬ' (predicted: 'b ə p ə r ə n')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'b ə r ə')
# WARNING: Incorrect prediction:	'ɕ a r a χ' (predicted: 'b ə r ə n')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə r ə r ə n')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə p ə r ə n')
# WARNING: Incorrect prediction:	'qʷ a p s' (predicted: 'b a a a')
# WARNING: Incorrect prediction:	'p ə n d͡ʒ' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b ə p ə r ə r ə n')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'b ə r ə n')
# WARNING: Incorrect prediction:	'x aː s a' (predicted: 'aː aː a a')
# WARNING: Incorrect prediction:	't͡sʼ ə f ə ʂ ħ a' (predicted: 'b a a a a a a')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'b a aː a')
# WARNING: Incorrect prediction:	'q a j ħ a x ə n' (predicted: 'n ə n ə n ə n')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'b a aː a aː a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'b a a a')
# WARNING: Incorrect prediction:	'z ə' (predicted: 'ə a')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'n ə n ə n ə n')
# WARNING: Incorrect prediction:	't͡ʃʼ a t ə l' (predicted: 'b ə p ə n')
# WARNING: Incorrect prediction:	'b a ɕ' (predicted: 'b a n')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'j a a a a n')
# WARNING: Incorrect prediction:	't χ ə n' (predicted: 'n ə n a n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'b ə n')
# WARNING: Incorrect prediction:	'ɡʲ ə j' (predicted: 'b ə n')
# WARNING: Incorrect prediction:	'ħ a ʐ' (predicted: 'b aː aː a')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 'b a a a a')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'n ə n ə n ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'b ə n ə n ə n')
# WARNING: Incorrect prediction:	'd a z a kʷʼ a n' (predicted: 'j a a a a n')
# WARNING: Incorrect prediction:	'p ʂ a' (predicted: 'b a a')
# WARNING: Incorrect prediction:	'b ʁʷ ə z a' (predicted: 'b a a a a')
# WARNING: Incorrect prediction:	't χ a ʑ ə n' (predicted: 'n ə n ə n a n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'b a a a a a')
# WARNING: Incorrect prediction:	'b ʐ aː qʷ a' (predicted: 'b a aː a a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'b ə n ə n ə n')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'b aː aː a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'p a aː a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'b a a a a')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 'b ə r ə n')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'n a a a a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 'b ə p ə p ə r ə')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'n ə n a n')
# WARNING: Incorrect prediction:	't͡ʃ ə p ɬ' (predicted: 'b ə p ə')
# WARNING: Incorrect prediction:	'ɡʷ a ɡʷ a n' (predicted: 'n ə n ə n')
# WARNING: Incorrect prediction:	't x ə d a ʐ' (predicted: 'b ə p ə n')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'j a a a a n')
# WARNING: Incorrect prediction:	'j ə s a n' (predicted: 'n ə n a n')
# WER:	100.00
# PER:	73.22
# epoch: 2
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'm a p a aː a a')
# WARNING: Incorrect prediction:	'ħ a w a' (predicted: 'm a a a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'm a p a')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə b b ə ə ə')
# WARNING: Incorrect prediction:	'ʁ a d͡ʒ ə d͡ʒ a n' (predicted: 'm a p a a a a n')
# WARNING: Incorrect prediction:	'ʔʷ a f ə n t͡ʂ a' (predicted: 'm a t a ə a a')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'm a t ə n')
# WARNING: Incorrect prediction:	'p χ a n tʼ a kʷʼ' (predicted: 'm a a a a a ə')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 'm a p a a a')
# WARNING: Incorrect prediction:	'w a r ə' (predicted: 'm a j')
# WARNING: Incorrect prediction:	'p aː p t͡ʃʼ a' (predicted: 'm aː p a a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'm a p a a a a aː a a')
# WARNING: Incorrect prediction:	'ʃ ə p χʷ' (predicted: 'm ə p ə')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'm a p aː aː aː a')
# WARNING: Incorrect prediction:	'ʃʷʼ a ʔʷ ə n' (predicted: 'm a n ə n')
# WARNING: Incorrect prediction:	'qʷ a z ə n' (predicted: 'm a n a n')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'm a a a a n')
# WARNING: Incorrect prediction:	'χ aː ʁ a' (predicted: 'ħ aː p a a')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 'm a t͡ʃʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'm a p a ə ə ə a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'n a a a a a a')
# WARNING: Incorrect prediction:	'z a ʁ a n' (predicted: 'm a n a n')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'm a t͡ʃʼ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə p aː')
# WARNING: Incorrect prediction:	'd a f a n' (predicted: 'm a a a n')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'm a r ə ə ə')
# WARNING: Incorrect prediction:	'd ə w' (predicted: 'b ə ə')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'm a a a a a')
# WARNING: Incorrect prediction:	'q a ʁ a ɬ a ʁʷ a n ə' (predicted: 'm a a a a a a a ə n')
# WARNING: Incorrect prediction:	'b z aː d͡ʒ a' (predicted: 'b a aː aː a')
# WARNING: Incorrect prediction:	'ʁ a p t͡sʼ aː kʷʼ a' (predicted: 'm a p a aː a a')
# WARNING: Incorrect prediction:	'ʁ a t͡ʃʼ ə n' (predicted: 'm a t͡ʃʼ a n')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'm a p a a ə ə')
# WARNING: Incorrect prediction:	'ɕ ə w aː n' (predicted: 'm ə n ə n')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'm ə p ə ə n')
# WARNING: Incorrect prediction:	'b ʁʷ a t a n' (predicted: 'm a p a a n')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'm a p a ə')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'm a p a a a aː aː aː')
# WARNING: Incorrect prediction:	'b l a w ə n' (predicted: 'm a j ə n')
# WARNING: Incorrect prediction:	'ʐʷ a t ə n' (predicted: 'm a n a n')
# WARNING: Incorrect prediction:	't͡ʃ a m ə' (predicted: 'm a j ə')
# WARNING: Incorrect prediction:	'ħ aː b l ə w' (predicted: 'm aː p ə ə ə')
# WARNING: Incorrect prediction:	'd aː d ə w' (predicted: 'm aː p ə')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'm a p ə p a a')
# WARNING: Incorrect prediction:	'ɬ ə kʷʼ a ʂ a n' (predicted: 'm a a a a a n')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'm a a a a a ə n')
# WARNING: Incorrect prediction:	'ʃ ə b z ə' (predicted: 'm ə b ə ə')
# WARNING: Incorrect prediction:	'b z a ɡʷ ə ħ' (predicted: 'm a b ə ə ə')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'm a p a aː aː aː a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'm a p ə ə ə n')
# WARNING: Incorrect prediction:	'ɡʷ ə m ə ʔʷ' (predicted: 'm ə ə ə ə')
# WARNING: Incorrect prediction:	'q a b ə' (predicted: 'm a r a ə')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 't͡ʃ ə n')
# WARNING: Incorrect prediction:	'p ʂ a b ə d a ɬ' (predicted: 'm a r a r a a')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'm a p a')
# WARNING: Incorrect prediction:	'ɕ a r a χ' (predicted: 'm a p a')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'm a n ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə b ə ə ə ə')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə b ə ə ə ə ə ə')
# WARNING: Incorrect prediction:	'qʷ a p s' (predicted: 'm a p a')
# WARNING: Incorrect prediction:	'p ə n d͡ʒ' (predicted: 'm ə n ə n')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'm ə p ə ə ə ə ə ə')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'm ə ə ə ə')
# WARNING: Incorrect prediction:	'x aː s a' (predicted: 'm aː aː a')
# WARNING: Incorrect prediction:	't͡sʼ ə f ə ʂ ħ a' (predicted: 'm a p a aː aː a a')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'm ə p a')
# WARNING: Incorrect prediction:	'q a j ħ a x ə n' (predicted: 'm a p a a ə n')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'm a t͡ʃʼ a n a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'm a w')
# WARNING: Incorrect prediction:	'z ə' (predicted: 'j ə n')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'm a a a a a ə n')
# WARNING: Incorrect prediction:	't͡ʃʼ a t ə l' (predicted: 'm a p ə ə')
# WARNING: Incorrect prediction:	'b a ɕ' (predicted: 'b a j')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'm a a a n')
# WARNING: Incorrect prediction:	't χ ə n' (predicted: 'm aː n ə n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a n')
# WARNING: Incorrect prediction:	'ɡʲ ə j' (predicted: 't͡ʃ ə j')
# WARNING: Incorrect prediction:	'ħ a ʐ' (predicted: 'm a w a')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 'm aː p a')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'm a a a a ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'm a p a a ə ə n')
# WARNING: Incorrect prediction:	'd a z a kʷʼ a n' (predicted: 'm a a a a n')
# WARNING: Incorrect prediction:	'p ʂ a' (predicted: 'm aː j a')
# WARNING: Incorrect prediction:	'b ʁʷ ə z a' (predicted: 'm ə ə ə j')
# WARNING: Incorrect prediction:	't χ a ʑ ə n' (predicted: 'm a p a ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'm a p a ə ə')
# WARNING: Incorrect prediction:	'b ʐ aː qʷ a' (predicted: 'b aː aː aː a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'm a t a a ə ə')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'm ə j a j')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː n a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'm a p aː t')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 'm ə b ə ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'm a a a a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 'm a p a a a ə ə ə')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'm ə j a n')
# WARNING: Incorrect prediction:	't͡ʃ ə p ɬ' (predicted: 'm a p ə')
# WARNING: Incorrect prediction:	'ɡʷ a ɡʷ a n' (predicted: 'm a n a n')
# WARNING: Incorrect prediction:	't x ə d a ʐ' (predicted: 'm ə p ə a')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'm a n a n')
# WARNING: Incorrect prediction:	'j ə s a n' (predicted: 'm a j a n')
# WER:	100.00
# PER:	61.91
# epoch: 3
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'q ə qʷ aː ʁ a')
# WARNING: Incorrect prediction:	'ħ a w a' (predicted: 'ħ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'q a w ħ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə b ə b ə b')
# WARNING: Incorrect prediction:	'ʁ a d͡ʒ ə d͡ʒ a n' (predicted: 'ʁ a ɡʷ ə ə ə a a n')
# WARNING: Incorrect prediction:	'ʔʷ a f ə n t͡ʂ a' (predicted: 'q a t ə n a a')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə ʁ a')
# WARNING: Incorrect prediction:	'p χ a n tʼ a kʷʼ' (predicted: 'q a t a a a a ə')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 'm a t ə ʁ a')
# WARNING: Incorrect prediction:	'w a r ə' (predicted: 'm a j')
# WARNING: Incorrect prediction:	'p aː p t͡ʃʼ a' (predicted: 'p p t͡sʼ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ħ aː n ə ʁʷ ə p t͡sʼ a')
# WARNING: Incorrect prediction:	'ʃ ə p χʷ' (predicted: 'ɕ ə p t͡sʼ ə')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'q a ħ aː pʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ a ʔʷ ə n' (predicted: 'q a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'qʷ a z ə n' (predicted: 'q a w ə n')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'q a j a j a n')
# WARNING: Incorrect prediction:	'χ aː ʁ a' (predicted: 'ħ aː n a')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː pʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a j ə ə ə ə x a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'z ə n a ʁʷ a a')
# WARNING: Incorrect prediction:	'z a ʁ a n' (predicted: 'z a ʁʷ a n')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'q a qʷ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʁ')
# WARNING: Incorrect prediction:	'd a f a n' (predicted: 'm a z a n')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p ə ə j ə j')
# WARNING: Incorrect prediction:	'd ə w' (predicted: 'd ə ə')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p a a a n a ʁ a')
# WARNING: Incorrect prediction:	'q a ʁ a ɬ a ʁʷ a n ə' (predicted: 'q a ʁ a ʁ a ʁʷ a n ə')
# WARNING: Incorrect prediction:	'b z aː d͡ʒ a' (predicted: 'b z aː p a')
# WARNING: Incorrect prediction:	'ʁ a p t͡sʼ aː kʷʼ a' (predicted: 'ʁ a p ħ aː pʼ a')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'q a qʷ a ħ ə w')
# WARNING: Incorrect prediction:	'ɕ ə w aː n' (predicted: 'ɕ ə n aː n')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ ə p t͡sʼ ə n')
# WARNING: Incorrect prediction:	'b ʁʷ a t a n' (predicted: 'b a a a a a n')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'q ə p a ʁʷ')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'q a ʁʷ a ʁ a ʁʷ aː ʁ')
# WARNING: Incorrect prediction:	'b l a w ə n' (predicted: 'b a p a n')
# WARNING: Incorrect prediction:	'ʐʷ a t ə n' (predicted: 'q a w ə n')
# WARNING: Incorrect prediction:	't͡ʃ a m ə' (predicted: 'm a w ə')
# WARNING: Incorrect prediction:	'ħ aː b l ə w' (predicted: 'ħ aː b ə ə ə')
# WARNING: Incorrect prediction:	'd aː d ə w' (predicted: 'z aː j ə w')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ə ə ħ a t a')
# WARNING: Incorrect prediction:	'ɬ ə kʷʼ a ʂ a n' (predicted: 'q ə t͡ʃʼ a t͡ʃʼ a n')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a a a a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'ʃ ə b z ə' (predicted: 'ə b b z ə')
# WARNING: Incorrect prediction:	'b z a ɡʷ ə ħ' (predicted: 'b z a n ə ħ')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a z a z a ħ aː ʁ a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'z a p ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'ɡʷ ə m ə ʔʷ' (predicted: 'ɡʷ ə ə ə ə')
# WARNING: Incorrect prediction:	'q a b ə' (predicted: 'q a z ə')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ɬ a n')
# WARNING: Incorrect prediction:	'p ʂ a b ə d a ɬ' (predicted: 'q a p ə r a b a ʁ')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'm a r a ʁ')
# WARNING: Incorrect prediction:	'ɕ a r a χ' (predicted: 'ɕ a r a ʁ a')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə p ə ə ə ə')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə ə ə ə p ħ ħ ħ ħ')
# WARNING: Incorrect prediction:	'qʷ a p s' (predicted: 'q a p s')
# WARNING: Incorrect prediction:	'p ə n d͡ʒ' (predicted: 'p ə ə ʁ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'z ə n ə ə ə ə ʁʷ ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ə t͡ʃʼ ə ə')
# WARNING: Incorrect prediction:	'x aː s a' (predicted: 'p aː a a')
# WARNING: Incorrect prediction:	't͡sʼ ə f ə ʂ ħ a' (predicted: 'q ə p ə ħ ħ a')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ʁʷ aː z a')
# WARNING: Incorrect prediction:	'q a j ħ a x ə n' (predicted: 'q a j a a ə ə n')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'ħ aː n aː ʁ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬ a w')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j a a a a a ə n')
# WARNING: Incorrect prediction:	't͡ʃʼ a t ə l' (predicted: 'q a t ə w')
# WARNING: Incorrect prediction:	'b a ɕ' (predicted: 'b a')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁʷ a n')
# WARNING: Incorrect prediction:	't χ ə n' (predicted: 't ħ ə n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a n')
# WARNING: Incorrect prediction:	'ɡʲ ə j' (predicted: 'ʁʷ ə j')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a w ə')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a a a a n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a p a a a a ħ ə n')
# WARNING: Incorrect prediction:	'd a z a kʷʼ a n' (predicted: 'z a z a t͡ʃʼ a n')
# WARNING: Incorrect prediction:	'p ʂ a' (predicted: 'p a a')
# WARNING: Incorrect prediction:	'b ʁʷ ə z a' (predicted: 'b ə ʁʷ ə')
# WARNING: Incorrect prediction:	't χ a ʑ ə n' (predicted: 't a t͡ʃ a ə ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'q a ʁʷ a ə ə')
# WARNING: Incorrect prediction:	'b ʐ aː qʷ a' (predicted: 'b aː ħ a a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a n a n ə ʁʷ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'qʷ aː j a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'z a z a ʁ a')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 'ɕ ə b ə ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'z a b ə ʁ a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 'q a p a a a r ə ħ ə ʁ')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ə a a n')
# WARNING: Incorrect prediction:	't͡ʃ ə p ɬ' (predicted: 'qʷ ə p p a')
# WARNING: Incorrect prediction:	'ɡʷ a ɡʷ a n' (predicted: 'ɡʷ a ʁʷ a n')
# WARNING: Incorrect prediction:	't x ə d a ʐ' (predicted: 't ə r a a ʁ')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'q ə ʁʷ a n')
# WARNING: Incorrect prediction:	'j ə s a n' (predicted: 'j ə j a n')
# WER:	97.00
# PER:	44.87
# epoch: 4
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʃʼ ə t͡ʃʼ ə ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w ə')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə p ə r ə d͡ʒ')
# WARNING: Incorrect prediction:	'ʁ a d͡ʒ ə d͡ʒ a n' (predicted: 'ʁ a d ə d͡z a n')
# WARNING: Incorrect prediction:	'ʔʷ a f ə n t͡ʂ a' (predicted: 'ʔ a r ə n')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə n a')
# WARNING: Incorrect prediction:	'p χ a n tʼ a kʷʼ' (predicted: 'p ʂ a n a a a ʃʼ ə')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə qʷ a')
# WARNING: Incorrect prediction:	'w a r ə' (predicted: 'w a r')
# WARNING: Incorrect prediction:	'p aː p t͡ʃʼ a' (predicted: 'p aː p t͡sʼ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ʂ ħ aː n ə p q a')
# WARNING: Incorrect prediction:	'ʃ ə p χʷ' (predicted: 't͡ʃ ə p q ə')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'q a ħ aː p t͡sʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ a ʔʷ ə n' (predicted: 'ʃʼ a ʔʷ ə n')
# WARNING: Incorrect prediction:	'qʷ a z ə n' (predicted: 'q a z ə n')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'q a r a j')
# WARNING: Incorrect prediction:	'χ aː ʁ a' (predicted: 'q aː ʁ a')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 'ʃʼ aː ʔʷ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a j q ə p ə x a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə ʁʷ a t͡ʃʼ aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʃʼ ə ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʁ')
# WARNING: Incorrect prediction:	'd a f a n' (predicted: 'd a r a n')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə r')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w a ʁ a')
# WARNING: Incorrect prediction:	'q a ʁ a ɬ a ʁʷ a n ə' (predicted: 'q a ʁ a ʁ a ʁʷ a n ə')
# WARNING: Incorrect prediction:	'b z aː d͡ʒ a' (predicted: 'b z aː ɬ a')
# WARNING: Incorrect prediction:	'ʁ a p t͡sʼ aː kʷʼ a' (predicted: 'ʁ a p t͡sʼ aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'ʔ a ʔ a ħ a qʷ')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ ə p t͡sʼ ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'kʷ ə ɬ a qʷ')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'q a qʷ a ʂ a ʁ aː z')
# WARNING: Incorrect prediction:	'ʐʷ a t ə n' (predicted: 'ʂ a t ə n')
# WARNING: Incorrect prediction:	'd aː d ə w' (predicted: 'd aː r ə w')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p p ə ʑ ə t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ɬ ə kʷʼ a ʂ a n' (predicted: 'ɬ ə t͡ʃʼ a ʐ a n')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a ʃʼ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'ʃ ə b z ə' (predicted: 't͡ʃ ə b z')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a d͡z a ʃʼ a qʷ a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'z a p ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'ɡʷ ə m ə ʔʷ' (predicted: 'ɡʷ ə r ə qʷ')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'p ʂ a b ə d a ɬ' (predicted: 'p ʂ a b ə d͡z a ɬ')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a r d͡ʒ')
# WARNING: Incorrect prediction:	'ɕ a r a χ' (predicted: 'ɕ a r a q')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a ə ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b l ə p ə p ə')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b z ə r p ə p q ə ħ')
# WARNING: Incorrect prediction:	'p ə n d͡ʒ' (predicted: 'p ə d͡ʒ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b l ə n ə r ə ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə t͡ʃʼ ə')
# WARNING: Incorrect prediction:	'x aː s a' (predicted: 'x aː x a')
# WARNING: Incorrect prediction:	't͡sʼ ə f ə ʂ ħ a' (predicted: 't͡ʃʼ ə p ə qʷ ħ a')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ aː z')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'p ə n aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬ a w d͡ʒ')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j a a a a x ə n')
# WARNING: Incorrect prediction:	't͡ʃʼ a t ə l' (predicted: 't͡ʃʼ a t ə d͡ʒ')
# WARNING: Incorrect prediction:	'b a ɕ' (predicted: 'b a')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁ a n')
# WARNING: Incorrect prediction:	't χ ə n' (predicted: 't ʂ ə n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a ʔʷ ə')
# WARNING: Incorrect prediction:	'ɡʲ ə j' (predicted: 'ʑ ə j')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a w ə w')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ ə qʷ ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a a a a t q ə n')
# WARNING: Incorrect prediction:	'd a z a kʷʼ a n' (predicted: 'd a d͡z a ʔʷ ə n')
# WARNING: Incorrect prediction:	'p ʂ a' (predicted: 'p q a')
# WARNING: Incorrect prediction:	'b ʁʷ ə z a' (predicted: 'b ʁʷ ə d͡ʒ a')
# WARNING: Incorrect prediction:	't χ a ʑ ə n' (predicted: 't a a ʑ ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'q a qʷ a r ə')
# WARNING: Incorrect prediction:	'b ʐ aː qʷ a' (predicted: 'b l aː qʷ a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ə ʁ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'ʂ ə j a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'm a r a ʃʼ ə')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r b ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j ɬ a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 't ħ a t͡ʃ a m a p ə ɬ')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ a n')
# WARNING: Incorrect prediction:	't͡ʃ ə p ɬ' (predicted: 't͡ʃ ə p q')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʂ ə ʁʷ a n')
# WARNING: Incorrect prediction:	'j ə s a n' (predicted: 'j ə r a n')
# WER:	83.00
# PER:	28.87
# epoch: 5
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʃʷ ə t͡ʃʼ aː ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w aː ʑ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə t ə b b ə f')
# WARNING: Incorrect prediction:	'ʁ a d͡ʒ ə d͡ʒ a n' (predicted: 'ʁ a d ə d͡ʒ d͡ʒ a n')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'p χ a n tʼ a kʷʼ' (predicted: 'p a a n a ʔ ə ʔʷ')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə ʂʷ a')
# WARNING: Incorrect prediction:	'p aː p t͡ʃʼ a' (predicted: 'p a p t͡sʼ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ħ a ʁʷ ʁʷ ə p q a')
# WARNING: Incorrect prediction:	'ʃ ə p χʷ' (predicted: 'ʃ ə qʷ')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'qʷ a ħ aː pʼ a')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'χ a r a n')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a χ ə r χ ə n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə n ʁʷ a t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʃʷ ə ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ɬ')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə j')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w a ʁ a')
# WARNING: Incorrect prediction:	'q a ʁ a ɬ a ʁʷ a n ə' (predicted: 'q a ɬ a a a ʁʷ a n ə')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'ʔ a ʂ ħ a qʷ')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ ə x ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'qʷ a ʃʷ a t͡ʃ a z aː z')
# WARNING: Incorrect prediction:	'ʐʷ a t ə n' (predicted: 'ʃʷ a t ə n')
# WARNING: Incorrect prediction:	'd aː d ə w' (predicted: 'd aː ɕ ə w')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ə ə ʑ ə ʁ a f')
# WARNING: Incorrect prediction:	'ɬ ə kʷʼ a ʂ a n' (predicted: 'ɬ ə kʷʼ a ʐ a n')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a ʔ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a d͡z a kʷʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'z a p ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'ɡʷ ə m ə ʔʷ' (predicted: 'ɡʷ a m ə ʔʷ')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'p ʂ a b ə d a ɬ' (predicted: 'p a a ə ə d͡ʒ a ɬ')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a b aː ɬ')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a ɡʷ ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə l ə m ə ɕ ə')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə r ə p x ə ʂ ħ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'ʑ ə n ə ə ɕ ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə ʔ ə')
# WARNING: Incorrect prediction:	't͡sʼ ə f ə ʂ ħ a' (predicted: 't͡ʃ ə r ə ʐ aː ħ a')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ aː z')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'kʷʼ ə n aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 't͡ʃ a w w')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j a a a a x ə n')
# WARNING: Incorrect prediction:	't͡ʃʼ a t ə l' (predicted: 't͡ʃ a t ə d͡ʒ')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʐ a n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a ʔʷ ə')
# WARNING: Incorrect prediction:	'ɡʲ ə j' (predicted: 'ə ə j')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a kʷ')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ qʷ ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a t͡ʃ a s t χ ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'qʷ a ʃʷ a f ə')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ə ʁ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'ʃʷ ə j aː')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː ʑ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'w a r a ʔʷ')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r b ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j ʐ ʐ a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 'ħ a kʷʼ a a m a p ə ɬ')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ a n')
# WARNING: Incorrect prediction:	't͡ʃ ə p ɬ' (predicted: 't͡ʃ ə p aː ɬ')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʃʷ ə ʁʷ a n')
# WER:	62.00
# PER:	19.13
# epoch: 6
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʃʷʼ ə ɡʲ aː ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w ʑ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə t ə r b ə f')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'p χ a n tʼ a kʷʼ' (predicted: 'p χ a n t͡ʃ a kʷʼ')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə ʂʷ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ħ aː ʁʷ aː p p a')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'qʷ a ħ aː pʼ a')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'χ a r a j')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a χ ə r ə ʂ a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə ʁʷ aː pʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʃʷ ə ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʁ')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə j')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w n a ʁ a')
# WARNING: Incorrect prediction:	'ʁ a p t͡sʼ aː kʷʼ a' (predicted: 'ʁ a p aː kʷʼ a')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'ʔ a ħ ħ a χʷ')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ x ə t͡sʼ ə n')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'kʷ ə ɬ a ʂʷ')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'qʷ aː ʃʷ a ʂ t͡ʃ a z')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ʂ ə ʑ ə ɡʲ a')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a t͡ʃʼ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'z a p ə kʲ ə n')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a r ə ɬ')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a ɡʲ ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə l ə m ə ɕ')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə r ə p x ə ħ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b ʑ ə n ə ɕ ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə t͡ʃʼ ə')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ aː z ə z')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'p aː n t͡ʃ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬʼ a w ʒ')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'j a j l a l a x ə n')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁ a n')
# WARNING: Incorrect prediction:	't χ ə n' (predicted: 't χʷ ə n')
# WARNING: Incorrect prediction:	'ɡʲ ə j' (predicted: 'ə ə')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a kʷ')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a p a s t χʷ ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'qʷ a qʷ a f ə')
# WARNING: Incorrect prediction:	'b ʐ aː qʷ a' (predicted: 'b aː qʷ a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ə ʁ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'ʃʷ aː j a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'w a r a ʔʷ')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r b ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j ə ʂ a n')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ a n')
# WARNING: Incorrect prediction:	't x ə d a ʐ' (predicted: 't x ə d a ʂ')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʃʷ ə ʁʷ a n')
# WER:	52.00
# PER:	14.43
# epoch: 7
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʃʷ ə t͡sʼ aː ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w ʑ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə t ə b ə f')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə n a')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə ʂʷ a')
# WARNING: Incorrect prediction:	'p aː p t͡ʃʼ a' (predicted: 'p aː p t͡sʼ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ħ a ʁʷ ʁʷ ə p t͡ʃ a')
# WARNING: Incorrect prediction:	'ʃ ə p χʷ' (predicted: 'ʃ ə p χʷ ə')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'qʷ a ħ aː pʼ a')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'χ a r a j a n')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a χ ə r χ ə a a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə n ʁʷ aː pʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʃʷ ə ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʂ')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə j')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w a ʁ a')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'ʔ a ʃʼ ħ a χʷ ə')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ ə t͡s p t͡sʼ ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'qʷ a qʷ a ʃʼ a ʁ aː z')
# WARNING: Incorrect prediction:	'ħ aː b l ə w' (predicted: 'ħ a b l ə w')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ɬ ə ʑ ə f')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a tʼ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a d͡z a t͡ʃ aː kʷʼ a')
# WARNING: Incorrect prediction:	'ɡʷ ə m ə ʔʷ' (predicted: 'ɡʷ ə m ə kʷʼ')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'p ʂ a b ə d a ɬ' (predicted: 'p ʂ a b ə d͡ʒ a ɬ')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a b l')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a n ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə l ə m ə p')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə ə p ə p x ə ħ ħ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b ʑ ə n ə s ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə ɬʼ ə')
# WARNING: Incorrect prediction:	'x aː s a' (predicted: 'x a s a')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ aː d͡z a')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'pʷʼ aː n aː t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬʼ a w ʒ ʒ ʒ')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j l a l a x ə n')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁ a n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a ʔ ə')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a kʷ ə kʷ')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ ə qʷ ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a p a s t χ ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a f ə' (predicted: 'qʷ a ʃʷ a f ə')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ʁ ə ʁ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'ʃʷ aː j a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː ɡʲ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'w a r a ɬʼ a')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r ə ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j ʐ a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 't ħ a m a p a p ɬ')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ ə n')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʃʷ ə ʁʷ a n')
# WER:	53.00
# PER:	14.96
# epoch: 8
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʃʷ ə t͡sʼ aː ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w ʑ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə t ə b ə l f')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə n a')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə ʂʷ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ħ aː n ʁʷ aː p t͡ʃ a')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'qʷ a ħ aː p t͡ʃʼ a')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'χ a r a j a n')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə n ʁʷ a t͡ʃ a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʃʷ ə ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʁ')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə j')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w n a ʁ a')
# WARNING: Incorrect prediction:	'ʁ a t͡ʃʼ ə n' (predicted: 'ʁ a t͡ʃ ə n')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ ə x ə t͡sʼ')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'kʷ ə ɬ a ʂʷ')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'qʷ a qʷ a t͡ʃ a ʁ aː z')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ʂ ə ʑ ə t͡ʃ a f')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a t͡ʃ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a d͡z a t͡ʃ aː kʷʼ a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'z a p ə kʲ ə n')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a b l')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a n ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə l ə m ə l')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b ʑ ə n ə r ɕ ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə ɬʼ ə')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ ə d͡z')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'tʷʼ aː n t͡ʃ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬʼ a w ʒ')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j l a l a x ə n')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁ a n')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a kʷ')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ ə qʷ ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a p ʔ a t χ ə n')
# WARNING: Incorrect prediction:	'p ʂ a' (predicted: 'p t͡ʃ a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ə ʁ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'ʃʷ ə aː j a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː ɡʲ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'w a r a ʃʷʼ')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r b ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j ɬ a n')
# WARNING: Incorrect prediction:	't ħ a kʷʼ m a p ə ɬ' (predicted: 'ħ ħ a m m a p ə ɬ')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ a n')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʃʷ ə ʁʷ a n')
# WARNING: Incorrect prediction:	'j ə s a n' (predicted: 'j s a n')
# WER:	47.00
# PER:	13.04
# epoch: 9
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʂʷ ə t͡sʼ aː ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w ʑ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə t ə b b ə f')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə ʂʷ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ħ aː n ʁʷ aː p t͡ʃ a')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'qʷ a ħ aː pʼ a')
# WARNING: Incorrect prediction:	'χ a r a j n' (predicted: 'χ a r a n')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a χ ə r χ a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə n ʁʷ aː n a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʂʷ ə ɬ ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʁ')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə j')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w n ʁ a')
# WARNING: Incorrect prediction:	'ʁ a t͡ʃʼ ə n' (predicted: 'ʁ a t͡ʃ ə n')
# WARNING: Incorrect prediction:	'ʔ a ʂ ħ a χʷ' (predicted: 'ʔ ə ʂ ħ a χʷ')
# WARNING: Incorrect prediction:	'ɕ x ə p t͡sʼ ə n' (predicted: 'ɕ ə x ə t͡sʼ ə n')
# WARNING: Incorrect prediction:	'kʷ ə ɬ a ʃʷ' (predicted: 'kʷ ə ɬ a ʂ')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'qʷ a ʂ a t͡ʃ a ʁ aː z')
# WARNING: Incorrect prediction:	'ʐʷ a t ə n' (predicted: 'ʂʷ a t ə n')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ʂ ə ʑ ə f f')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a t͡ʃ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a d͡z a t͡ʃ aː kʷʼ a')
# WARNING: Incorrect prediction:	'z a p ə kʲʼ ə n' (predicted: 'z a p ə kʲ ə n')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a j ɬ')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a n ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə l ə m ə ʃ ə')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə r ə p x ə ʂ ħ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b ʑ ə n ə s ə ʁʷ ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə ɬʼ ə')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ ə d͡z aː z')
# WARNING: Incorrect prediction:	'pʷʼ aː n t͡ʃ a' (predicted: 'pʷʼ ə n aː t͡ʃ a')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬʼ a w ʒ')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j l a l a x ə n')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁ a n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a ʔʷ ə')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a kʷ')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ ə n ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a p a t t χ ə n')
# WARNING: Incorrect prediction:	'p ʂ a' (predicted: 'p t͡ʃ a')
# WARNING: Incorrect prediction:	'b ʁʷ ə z a' (predicted: 'b ʁʷ aː z a')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ə ʁ')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː ɡʲ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'w a r a ɬʼ')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r b ə')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j ʐ a n')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ a n')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʂʷ ə ʁʷ ʁʷ a n')
# WARNING: Incorrect prediction:	'j ə s a n' (predicted: 'j s a n')
# WER:	50.00
# PER:	13.39
# epoch: 10
# WARNING: Incorrect prediction:	'ʃʷʼ t͡sʼ aː ʁ a' (predicted: 'ʂʷ ə t͡sʼ aː ʁ a')
# WARNING: Incorrect prediction:	'ɬ a w ə ʑ' (predicted: 'ɬ a w ʑ')
# WARNING: Incorrect prediction:	'b a t ə r b ə f' (predicted: 'b ə t ə r b f')
# WARNING: Incorrect prediction:	'ʔʷ a f ə n t͡ʂ a' (predicted: 'ʔʷ a f ə n t͡ʂʼ a')
# WARNING: Incorrect prediction:	'ʁʷ ə t͡ʂʼ ə n a' (predicted: 'ʁʷ ə t͡ʃʼ ə n a')
# WARNING: Incorrect prediction:	't͡ʃ a m ə ʃʷ a' (predicted: 't͡ʃ a m ə ʂʷ a')
# WARNING: Incorrect prediction:	'ʂ ħ aː n ʁʷ ə p t ʂ a' (predicted: 'ʂ ħ aː n ʁʷ aː p q a')
# WARNING: Incorrect prediction:	'qʷ a ħ aː pʼ' (predicted: 'qʷ a ħ aː pʼ a')
# WARNING: Incorrect prediction:	't͡ʃ aː kʷʼ a' (predicted: 't͡ʃʼ aː kʷʼ a')
# WARNING: Incorrect prediction:	'j a χ ə r χ ə ʃ a n' (predicted: 'j a χ ə r χ ə a a n')
# WARNING: Incorrect prediction:	'w n aː ʁʷ a t͡sʼ a' (predicted: 'w ə n ʁʷ a t͡ʃʼ a')
# WARNING: Incorrect prediction:	'ʃʷʼ ə ɬ a ʁʷ ə n' (predicted: 'ʂʷ ə ɬ a ʁʷ ə n')
# WARNING: Incorrect prediction:	'n ə b aː t͡ʂ' (predicted: 'n ə b aː ʁ')
# WARNING: Incorrect prediction:	'p sʼ ə r ə j' (predicted: 'p s ə r ə j')
# WARNING: Incorrect prediction:	'p s a w a n ʁ a' (predicted: 'p s a w a ʁ a')
# WARNING: Incorrect prediction:	'ɕ ə w aː n' (predicted: 'ɕ ə w ə n')
# WARNING: Incorrect prediction:	'qʷ a ʂʷ a t͡ʃ a ʁ a z' (predicted: 'qʷ a ʂ a t͡ʃ a ʁ a z')
# WARNING: Incorrect prediction:	'p ɬ ə ʑ ɡʲ a f' (predicted: 'p ʂ ə ʑ ə ʂ f')
# WARNING: Incorrect prediction:	'z a p a t͡ʂʼ a t͡ʃʼ ə n' (predicted: 'z a p a t͡ʃ a t͡ʃʼ ə n')
# WARNING: Incorrect prediction:	'z a d͡z a t͡ʃʼ aː kʷʼ a' (predicted: 'z a d͡z a t͡ʃ aː kʷʼ a')
# WARNING: Incorrect prediction:	'ʐʷ ə n' (predicted: 'ʐ ə n')
# WARNING: Incorrect prediction:	'd a j aː ɬ' (predicted: 'd a b ɬ')
# WARNING: Incorrect prediction:	'ɕ a r a χ' (predicted: 'ɕ a ɕ a χ')
# WARNING: Incorrect prediction:	'ʁʷ a ɣ ə n' (predicted: 'ʁʷ a n ə n')
# WARNING: Incorrect prediction:	'b ə l ə m ə l ə' (predicted: 'b ə l ə m ə p')
# WARNING: Incorrect prediction:	'b ɣ ə r ə p x ə ʂ ħ' (predicted: 'b ə ə ə ə p x ə ħ')
# WARNING: Incorrect prediction:	'b ʑ ə n ə f ɕ ə ʁʷ' (predicted: 'b ʑ ə n ə f ə ʁʷ')
# WARNING: Incorrect prediction:	'p ɕ ə ɬʼ' (predicted: 'p ɕ ə ɬʼ ə')
# WARNING: Incorrect prediction:	'ɡʷ aː d͡z' (predicted: 'ɡʷ ə d͡z a z')
# WARNING: Incorrect prediction:	'ɬʼ a w ə ʒ' (predicted: 'ɬʼ a w ʒ')
# WARNING: Incorrect prediction:	'q a j ɬ a ɬ a x ə n' (predicted: 'q a j l a l a x ə n')
# WARNING: Incorrect prediction:	'm a ʁ a ʁ a n' (predicted: 'ʁ a ʁ a n')
# WARNING: Incorrect prediction:	'n a ʔʷ' (predicted: 'n a ɡʷ ə')
# WARNING: Incorrect prediction:	't ħ a t͡ʃʷ' (predicted: 't ħ a kʷ')
# WARNING: Incorrect prediction:	'j a n a qʷ a qʷ a n' (predicted: 'j a n a qʷ a qʷ ə n')
# WARNING: Incorrect prediction:	'j a pʼ a s t χ ə n' (predicted: 'j a pʼ a s t ə n')
# WARNING: Incorrect prediction:	'z a qʷ a ʃ n ə ʁ' (predicted: 'z a qʷ a n ə ʁ')
# WARNING: Incorrect prediction:	'ʂʷ aː j a' (predicted: 'ʃʷ aː j a')
# WARNING: Incorrect prediction:	'm aː' (predicted: 'm aː ʑ a')
# WARNING: Incorrect prediction:	'w a r a d aː ʔʷ' (predicted: 'w a r a ɬʼ')
# WARNING: Incorrect prediction:	't͡ʃ ə r b ə t͡ʃ' (predicted: 't͡ʃ ə r b ə s')
# WARNING: Incorrect prediction:	'd a j ʂ a n' (predicted: 'd a j qʷ a n')
# WARNING: Incorrect prediction:	'j a b ɣ ə n' (predicted: 'b ɣ a n')
# WARNING: Incorrect prediction:	'ʃʷ ʁʷ a n' (predicted: 'ʃʷ ə ʁʷ a n')
# WER:	44.00
# PER:	11.13

# %% [markdown]
# ## Prediction

# %%
checkpoint = torch.load(root_path+f"models/ady/10.pt")
model.load_state_dict(checkpoint['state_dict'])
_, translated = inference(model, test_iter, SRC, TRG, True, 64)

# %%
next(iter(test_iter))
# Out:
# [torchtext.legacy.data.batch.Batch of size 1]
# 	[.SRC]:[torch.cuda.LongTensor of size 9x1 (GPU 0)]
# 	[.TRG]:[torch.cuda.LongTensor of size 3x1 (GPU 0)]

# %%
def generate_final_prediction(test_file_path, translated, output_file_path):
  '''
  test_file_path -- the file path to the test file
  translated -- a list of lists that contain predictions
  output_file_path -- output file path that you will create
  '''
  with open(test_file_path, "r", encoding="utf-8") as f:
    gold = f.read().splitlines()
  processed_translated = []
  for word in translated:
    curr_word = []
    for char in word:
      if char == "<eow>":
        break
      if char != "<eow>" and char != "<pad>":
        curr_word.append(char)
    processed_translated.append(curr_word)
  with open(output_file_path, "w", encoding="utf-8") as fout:
    for g, t in zip(gold, processed_translated):
      fout.write(g + "\t" + " ".join(t) + "\n")

# %%
ady_test_path = data_path + "ady_test.tsv"

# %%
generate_final_prediction(ady_test_path, translated, root_path+"predictions/ady_preds.tsv")
