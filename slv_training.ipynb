# %% [markdown]
# ### Note: Model is trained on Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import unicodedata
import string
import re
import random
import time
import datetime
import math

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
import torchtext

import spacy
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read data

# %%
data_path = "/content/drive/MyDrive/g2p/data_new/slv/"
root_path = "/content/drive/MyDrive/g2p/"

# %%
df_slv_train = pd.read_csv(data_path + "slv_train.tsv", sep='\t', header=None, encoding='utf-8').rename(columns={0:"grapheme", 1:"phoneme"})
df_slv_dev = pd.read_csv(data_path + "slv_dev.tsv", sep='\t', header=None, encoding='utf-8').rename(columns={0:"grapheme", 1:"phoneme"})

# %%
df_slv_train.head()
# Out:
#       grapheme                  phoneme
# 0     kraljica       k r a l j ìː t͡s a
# 1  najstarejši  n á j s t a r ɛ́ː j ʃ i
# 2         teta                t ɛ̀ː t a
# 3     romunija         r ɔ m ùː n i j a
# 4      uporaba           u p ɔ r áː b a

# %%
df_slv_dev.head()
# Out:
#    grapheme           phoneme
# 0     roman        r ɔ m áː n
# 1   število    ʃ t ɛ ʋ ìː l ɔ
# 2     tipka        t íː p k a
# 3   apartma    a p a r t m áː
# 4  aluminij  a l u m ìː n i j

# %%
df_slv_train.shape
# Out:
# (700, 2)

# %%
df_slv_dev.shape
# Out:
# (100, 2)

# %% [markdown]
# ## Use torchtext to prepare data

# %%
def tokenize_grapheme(text):
    """
    Tokenizes French text from a string into a list of strings (tokens)
    """
    return list(text)

# %%
def tokenize_phoneme(text):
    """
    Tokenizes French text from a string into a list of strings (tokens)
    """
    return text.split()

# %%
df_slv_train_gra = df_slv_train["grapheme"].apply(tokenize_grapheme)

df_slv_train_gra
# Out:
# 0               [k, r, a, l, j, i, c, a]
# 1      [n, a, j, s, t, a, r, e, j, š, i]
# 2                           [t, e, t, a]
# 3               [r, o, m, u, n, i, j, a]
# 4                  [u, p, o, r, a, b, a]
#                      ...
# 695                   [a, n, d, r, e, j]
# 696                      [p, o, m, e, n]
# 697                            [b, a, s]
# 698                            [v, e, č]
# 699                      [l, a, ž, j, i]
# Name: grapheme, Length: 700, dtype: object

# %%
df_slv_train_pho = df_slv_train["phoneme"].apply(tokenize_phoneme)

df_slv_train_pho
# Out:
# 0              [k, r, a, l, j, ìː, t͡s, a]
# 1      [n, á, j, s, t, a, r, ɛ́ː, j, ʃ, i]
# 2                           [t, ɛ̀ː, t, a]
# 3                [r, ɔ, m, ùː, n, i, j, a]
# 4                   [u, p, ɔ, r, áː, b, a]
#                       ...
# 695                   [a, n, d, r, ɛ̀ː, j]
# 696                       [p, ɔ, m, ɛ́, n]
# 697                             [b, áː, s]
# 698                           [ʋ, ɛ́, t͡ʃ]
# 699                       [l, áː, ʒ, j, i]
# Name: phoneme, Length: 700, dtype: object

# %%
SRC = torchtext.legacy.data.Field(tokenize = tokenize_grapheme, 
            init_token = '<sos>', # since initial encoder hidden state is always set to zero, the network can figure out that the time step is 0 and this token is optional
            eos_token = '<eow>', 
            lower = True)
TRG = torchtext.legacy.data.Field(tokenize = tokenize_phoneme, 
            init_token = '<sow>', 
            eos_token = '<eow>', 
            lower = True)

# %%
assert SRC.tokenize("hello") == ['h', 'e', 'l', 'l', 'o']
assert TRG.tokenize("b a b ɛ ɬ") == ['b', 'a', 'b', 'ɛ', 'ɬ']

# %%
train, val = torchtext.legacy.data.TabularDataset.splits(
    path=data_path, train='slv_train.tsv',validation='slv_dev.tsv', 
    format='tsv', skip_header=False, fields=[('SRC', SRC), ('TRG', TRG)])

test = torchtext.legacy.data.TabularDataset(
    path=data_path + 'new_slv_test.tsv',
    format='tsv', skip_header=False, fields=[('SRC', SRC), ('TRG', TRG)])

# %%
print(next(iter(train)).TRG)
# Out:
# ['k', 'r', 'a', 'l', 'j', 'ìː', 't͡s', 'a']

# %%
print(next(iter(train)).SRC)
# Out:
# ['k', 'r', 'a', 'l', 'j', 'i', 'c', 'a']

# %%
# build vocab
SRC.build_vocab(train)
TRG.build_vocab(train)

# %%
len(SRC.vocab)
# Out:
# 29

# %%
print(SRC.vocab.itos)
# Out:
# ['<unk>', '<pad>', '<sos>', '<eow>', 'a', 'e', 'o', 'i', 'r', 'n', 't', 's', 'l', 'k', 'j', 'v', 'd', 'p', 'm', 'b', 'z', 'č', 'g', 'u', 'š', 'c', 'ž', 'h', 'f']

# %%
print(TRG.vocab.itos)
# Out:
# ['<unk>', '<pad>', '<sow>', '<eow>', 'a', 'r', 't', 'n', 's', 'ɔ', 'k', 'l', 'i', 'ʋ', 'j', 'ɛ', 'p', 'd', 'm', 'áː', 'b', 'óː', 'z', 'éː', 'àː', 'ə', 't͡ʃ', 'ʃ', 'íː', 'ɡ', 'ìː', 'á', 'èː', 't͡s', 'ɔ̀ː', 'u', 'ʒ', 'x', 'ɛ̀ː', 'òː', 'ɔ́', 'ùː', 'úː', 'f', 'ɛ́', 'ɛ́ː', 'ɔ́ː', 'ə́', 'í', 'ə̀', 'd͡ʒ']

# %%
print(TRG.vocab.stoi['<pad>'])
# Out:
# 1

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
from torchtext.legacy.data import Iterator, BucketIterator
train_iter = BucketIterator(
        train,
        batch_size=1,
        device=device,
        sort_key=len,
        shuffle=True)
dev_iter, test_iter = Iterator.splits(
        (val, test),
        batch_sizes=(1,1),
        device=device,
        sort=False,
        shuffle=False)

# %%
# batch example of training data
for batch in train_iter:
    src = batch.SRC
    trg = batch.TRG
    print('tensor size of source language:', src.shape)
    print('tensor size of target language:', trg.shape)
    print('the tensor of first example in target language:', trg[:,0])
    break
# Out:
# tensor size of source language: torch.Size([4, 1])
# tensor size of target language: torch.Size([4, 1])
# the tensor of first example in target language: tensor([ 2, 22,  4,  3], device='cuda:0')

# %% [markdown]
# ## Build seq2seq+attention model

# %% [markdown]
# ### Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, n_layers, dropout):
        super().__init__()

        self.emb_dim = emb_dim
        self.enc_hid_dim = enc_hid_dim
        self.dropout = dropout
        self.n_layers = n_layers

        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.lstm = nn.LSTM(emb_dim, enc_hid_dim, n_layers, dropout=dropout, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        
        #src = [src len, batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src len, batch size, emb dim]
        
        outputs, (hidden, cell) = self.lstm(embedded)
       
        # outputs are always from the top hidden layer, if bidirectional outputs are concatenated.
        # outputs = [sequence_length, batch_size, hidden_dim * num_directions]
        # hidden = [num_layers * num_directions, batch_size, hidden_size]
        # cell = [num_layers * num_directions, batch_size, hidden_size]

        a, b, c = outputs.shape
        h_a, h_b, h_c = hidden.shape

        return outputs.view(a, b, 2, -1).mean(dim=2), (hidden.view(self.n_layers, 2, h_b, h_c).mean(dim=1).squeeze(0), cell.view(self.n_layers, 2, h_b, h_c).mean(dim=1))

# %% [markdown]
# ### Attention

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        
        self.W_a = nn.Linear(enc_hid_dim + dec_hid_dim, dec_hid_dim)
        self.v_a = nn.Parameter(torch.rand(dec_hid_dim)) # same as doing nn.Linear(dec_hid_dim, 1, bias=False)
        self.neg_inf = torch.tensor(-1e7, device=device)
        
    def forward(self, hidden, encoder_outputs, attention_mask):
        #(decoder) hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim]
        #attention_mask = [batch_size, src_len]
        
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #repeat decoder hidden state src_len-1 times
        # print("attnetion forward encoder outputs: ", encoder_outputs.shape) # 2 x 2 x 512
        # print("attnetion forward hidden: ", hidden.shape) # 2 x 2 x 512
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #hidden = [batch size, src len, dec hid dim]
        #encoder_outputs = [batch size, src len, enc hid dim]
        
        # attention scoring function - part 1 - tanh(W_a[s;h])
        energy = torch.tanh(self.W_a(torch.cat((hidden, encoder_outputs), dim = 2))) 
        
        #energy = [batch size, src len, dec hid dim]
        
        energy = energy.permute(0, 2, 1)
        
        #energy = [batch size, dec hid dim, src len]
        
        #v = [dec hid dim]
        
        v = self.v_a.repeat(batch_size, 1).unsqueeze(1)
        
        #v = [batch size, 1, dec hid dim]
        
        # attention scoring function - part 2 - v_a(tanh(W_a[s;h]))
        attention = torch.bmm(v, energy).squeeze(1)
        
        #attention= [batch size, src len]

        # before computing the softmax, set attention to pad tokens to -infinity
        attention[attention_mask] = self.neg_inf

        # attention scoring function - part 2 - softmax(v_a(tanh(W_a[s;h])))
        return F.softmax(attention, dim=1)

# %% [markdown]
# ### Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, n_layers, dropout, attention):
        super().__init__()
        
        self.output_dim = output_dim
        self.attention = attention
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.LSTM(enc_hid_dim + emb_dim, dec_hid_dim, n_layers, dropout=dropout)
        
        self.fc_out = nn.Linear(enc_hid_dim + dec_hid_dim + emb_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell, encoder_outputs, attention_mask):
             
        #input = [batch size]
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim]
        #attention_mask = [batch_size, src_len]
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
        # get the attention probabilities
        attention_weights = self.attention(hidden, encoder_outputs, attention_mask)
                
        #attention_weights = [batch size, src len]
        
        attention_weights = attention_weights.unsqueeze(1)
        
        #a = [batch size, 1, src len]
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #encoder_outputs = [batch size, src len, enc hid dim]
        # perform weighted sum of encoder hidden states to get attention output
        weighted = torch.bmm(attention_weights, encoder_outputs)
        
        #weighted = [batch size, 1, enc hid dim]
        
        weighted = weighted.permute(1, 0, 2)
        
        #weighted = [1, batch size, enc hid dim]
        # concatenate the attention outputs (or context vectors) with the current decoder input
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        
        #rnn_input = [1, batch size, (enc hid dim) + emb dim]
        output, (hidden, cell) = self.rnn(rnn_input, (hidden.unsqueeze(0), cell))
        
        #output = [seq len, batch size, dec hid dim * n directions]
        #hidden = [n layers * n directions, batch size, dec hid dim]
        
        #seq len, n layers and n directions will always be 1 in this decoder, therefore:
        #output = [1, batch size, dec hid dim]
        #hidden = [1, batch size, dec hid dim]
        #this also means that output == hidden
        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        # classification over the entire word vocabulary
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden.squeeze(0), cell, attention_weights

# %% [markdown]
# ### Seq2seq with attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src len, batch size]
        #trg = [trg len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use teacher forcing 75% of the time
        batch_size = src.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim

        # create encoder attention mask, set attention to pad tokens to -infinity 
        attention_mask = (src == SRC.vocab.stoi[SRC.pad_token]).transpose(0, 1)
        # attention_mask = [batch size, src len]
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        # save the encoder-decoder attention weights
        # all_attention_weights = [batch_size, trg len-1, src len ]
        all_attention_weights = torch.zeros(trg.shape[1], trg.shape[0]-1, src.shape[0])
        #encoder_outputs is all hidden states of the input sequence, back and forwards
        #hidden is the final forward and backward hidden states, passed through a linear layer
        encoder_outputs, (hidden, cell) = self.encoder(src)
                
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        for t in range(1, trg_len):
            
            #insert input token embedding, previous hidden state and all encoder hidden states
            #receive output tensor (predictions) and new hidden state
            output, hidden, cell, attention_weights = self.decoder(input, hidden, cell, encoder_outputs, attention_mask)
            
            # all_attention_weights[t-1] = [src len, batch size]
            all_attention_weights[:,t-1,:] = attention_weights.squeeze(1)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1

        return outputs,all_attention_weights

# %% [markdown]
# ### Train the seq2seq model

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)

# hyperparameters
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
ENC_HID_DIM = 512
DEC_HID_DIM = 512
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5
N_LAYERS = 1
LEARNING_RT = 0.001

# model components
attn = Attention(ENC_HID_DIM, DEC_HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, N_LAYERS, DEC_DROPOUT, attn)
model = Seq2Seq(enc, dec, device).to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
# weight init ## pre-trained embeddings later
def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)
            
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(29, 256)
#     (lstm): LSTM(256, 512, dropout=0.5, bidirectional=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (W_a): Linear(in_features=1024, out_features=512, bias=True)
#     )
#     (embedding): Embedding(51, 256)
#     (rnn): LSTM(768, 512, dropout=0.5)
#     (fc_out): Linear(in_features=1280, out_features=51, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
optimizer = optim.Adam(model.parameters())

# %%
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
print('<pad> token index: ',TRG_PAD_IDX)
## we will ignore the pad token in true target set
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
# Out:
# <pad> token index:  1

# %%
clip = 1
model.train()

for i, batch in enumerate(train_iter):

    src = batch.SRC
    trg = batch.TRG
    optimizer.zero_grad()
    output,_ = model(src, trg)
    #trg = [trg len, batch size]
    #output = [trg len, batch size, output dim]

    output_dim = output.shape[-1]

    output = output[1:].view(-1, output_dim)
    trg = trg[1:].view(-1)

    #trg = [(trg len - 1) * batch size]
    #output = [(trg len - 1) * batch size, output dim]

    loss = criterion(output, trg)

    loss.backward()

    torch.nn.utils.clip_grad_norm_(model.parameters(), clip)

    optimizer.step()

    print(loss/src.shape[1])
    break

    # 2, 2, 512; ==> 1, 2, 1024; <-
# Out:
# tensor(3.9316, device='cuda:0', grad_fn=<DivBackward0>)

# %% [markdown]
# ## Train

# %%
def train_func(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.SRC
        trg = batch.TRG
        
        optimizer.zero_grad()
        
        output,_ = model(src, trg)
        
        #trg = [trg len, batch size]
        #output = [trg len, batch size, output dim]
        
        output_dim = output.shape[-1]
        
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)
        
        #trg = [(trg len - 1) * batch size]
        #output = [(trg len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.SRC
            trg = batch.TRG

            output,_ = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg len, batch size]
            #output = [trg len, batch size, output dim]

            output_dim = output.shape[-1]
            
            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)

            #trg = [(trg len - 1) * batch size]
            #output = [(trg len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 10
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train_func(model, train_iter, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, dev_iter, criterion)
    
    end_time = time.time()
    state_dict_model = model.state_dict() 
    state = {
        'epoch': epoch,
        'state_dict': state_dict_model,
        'optimizer': optimizer.state_dict()
        }
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    torch.save(state, root_path + "models/slv/" +str(epoch+1)+".pt")
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f}')
# Out:
# Epoch: 01 | Time: 0m 12s
# 	Train Loss: 2.972
# 	 Val. Loss: 2.866
# Epoch: 02 | Time: 0m 13s
# 	Train Loss: 2.613
# 	 Val. Loss: 2.594
# Epoch: 03 | Time: 0m 13s
# 	Train Loss: 1.692
# 	 Val. Loss: 1.094
# Epoch: 04 | Time: 0m 13s
# 	Train Loss: 0.681
# 	 Val. Loss: 0.856
# Epoch: 05 | Time: 0m 13s
# 	Train Loss: 0.461
# 	 Val. Loss: 0.629
# Epoch: 06 | Time: 0m 13s
# 	Train Loss: 0.356
# 	 Val. Loss: 0.668
# Epoch: 07 | Time: 0m 13s
# 	Train Loss: 0.270
# 	 Val. Loss: 0.671
# Epoch: 08 | Time: 0m 12s
# 	Train Loss: 0.189
# 	 Val. Loss: 0.774
# Epoch: 09 | Time: 0m 12s
# 	Train Loss: 0.149
# 	 Val. Loss: 0.806
# Epoch: 10 | Time: 0m 13s
# 	Train Loss: 0.096
# 	 Val. Loss: 0.844

# %% [markdown]
# ## Evluation

# %%
def inference(model, dev_iter, src_vocab, trg_vocab, attention = True, max_trg_len = 64):
    '''
    Function for translation inference

    Input: 
    model: translation model;
    trg_vocab: Target torchtext Field
    attention: the model returns attention weights or not.
    max_trg_len: the maximal length of translation text (optinal), default = 64

    Output:
    Corpus BLEU score.
    '''
    from torchtext.legacy.data import TabularDataset
    from torchtext.legacy.data import Iterator

    # convert index to text string
    def convert_itos(convert_vocab, token_ids):
        list_string = []
        for i in token_ids:
            if i == convert_vocab.vocab.stoi['<eos>']:
                break
            else:
                token = convert_vocab.vocab.itos[i]
                list_string.append(token)
        return list_string
  
    model.eval()
    all_trg = []
    all_translated_trg = []

    TRG_PAD_IDX = trg_vocab.vocab.stoi[trg_vocab.pad_token]

    with torch.no_grad():
    
        for i, batch in enumerate(dev_iter):

            src = batch.SRC
            #src = [src len, batch size]

            trg = batch.TRG
            #trg = [trg len, batch size]

            batch_size = trg.shape[1]

            # create a placeholder for traget language with shape of [max_trg_len, batch_size] where all the elements are the index of <pad>. Then send to device
            trg_placeholder = torch.Tensor(max_trg_len, batch_size)
            trg_placeholder.fill_(TRG_PAD_IDX)
            trg_placeholder = trg_placeholder.long().to(device)
            if attention == True:
              output,_ = model(src, trg_placeholder, 0) #turn off teacher forcing
            else:
              output,_ = model(src, trg_placeholder, 0) #turn off teacher forcing
            # get translation results, we ignor first token <sos> in both translation and target sentences. 
            # output_translate = [(trg len - 1), batch, output dim] output dim is size of target vocabulary.
            output_translate = output[1:]
            # store gold target sentences to a list 
            all_trg.append(trg[1:].cpu())

            # Choose top 1 word from decoder's output, we get the probability and index of the word
            prob, token_id = output_translate.data.topk(1)
            translation_token_id = token_id.squeeze(2).cpu()

            # store gold target sentences to a list 
            all_translated_trg.append(translation_token_id)
      
    all_gold_text = []
    all_translated_text = []
    for i in range(len(all_trg)): 
        cur_gold = all_trg[i]
        cur_translation = all_translated_trg[i]
        for j in range(cur_gold.shape[1]):
            gold_convered_strings = convert_itos(trg_vocab,cur_gold[:,j])
            trans_convered_strings = convert_itos(trg_vocab,cur_translation[:,j])

            all_gold_text.append(gold_convered_strings)
            all_translated_text.append(trans_convered_strings)

    return all_gold_text, all_translated_text

# %%
def get_validation_score(model_best, dev_iter, src_vocab, trg_vocab, out_fp):
  gold, translated = inference(model_best, dev_iter, src_vocab, trg_vocab, True, 64)
  processed_gold = []
  for word in gold:
    curr_word = []
    for char in word:
      if char != "<eow>" and char != "<pad>":
        curr_word.append(char)
    processed_gold.append(curr_word)
  processed_translated = []
  for word in translated:
    curr_word = []
    for char in word:
      if char == "<eow>":
        break
      if char != "<eow>":
        curr_word.append(char)
    processed_translated.append(curr_word)
  with open(out_fp, "w", encoding="utf-8") as fout:
    for g, t in zip(processed_gold, processed_translated):
      fout.write(" ".join(g) + "\t" + " ".join(t) + "\n")

# %%
# %cd /content/drive/MyDrive/g2p
# Out:
# /content/drive/MyDrive/g2p

# %%
for i in range(1, 11):
  print("epoch:", i)
  checkpoint = torch.load(root_path+f"models/slv/{i}.pt")
  model.load_state_dict(checkpoint['state_dict'])
  get_validation_score(model, dev_iter, SRC, TRG, root_path+"evaluation/slv_gold_translated.tsv")
  # !python evaluate.py /content/drive/MyDrive/g2p/evaluation/slv_gold_translated.tsv
# Out:
# epoch: 1
# WARNING: Incorrect prediction:	'r ɔ m áː n' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'ʃ t ɛ ʋ ìː l ɔ' (predicted: 'ɔ r n n n i i')
# WARNING: Incorrect prediction:	't íː p k a' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'ɔ r n n n i t')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'ɔ ɔ n n n n i')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'ɔ ɔ n ɔ n n n i')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	'n a p r áː ʋ a' (predicted: 'ɔ r ɔ n n i t')
# WARNING: Incorrect prediction:	's t á' (predicted: 't éː t')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'p ɔ n n a')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 'ɔ ɔ n ɔ n n n i i')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 'ɔ r n n n a')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	't' (predicted: 't óː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'ɔ r n n n a')
# WARNING: Incorrect prediction:	'b óː d ɔ' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'ɔ r n n n i t')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'ɔ ɔ n ɔ n n n n i i')
# WARNING: Incorrect prediction:	's p r ɛ m éː m b a' (predicted: 'ɔ ɔ n ɔ n n n i i')
# WARNING: Incorrect prediction:	'i ɡ r àː t i' (predicted: 'p ɔ n n a t')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'ɔ r n n n i')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'm èː t ə t')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm èː t ə t')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'p ɔ t èː t i')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'p ɔ n n a t')
# WARNING: Incorrect prediction:	'ʒ àː r a' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	's t ɔ́ ʋ' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	's l ɔ ʋ èː n ə t͡s' (predicted: 'ɔ ɔ n ɔ n n i t')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'n í t' (predicted: 't éː s')
# WARNING: Incorrect prediction:	'k r' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	's í t' (predicted: 't éː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'ɔ r n n n i')
# WARNING: Incorrect prediction:	'b r úː t ɔ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	'd i j àː k' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɔ n n n n i')
# WARNING: Incorrect prediction:	'n á j b óː l j ɛ' (predicted: 'ɔ ɔ n n n n i')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'p ɔ n n a')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'ɔ ɔ n ɔ n n n i i')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	't ɛ̀ː t͡ʃ i' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'm ɔ̀ː t͡ʃ i' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ɔ r n n n i i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'p ɔ n n a t')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 't éː s')
# WARNING: Incorrect prediction:	'ɔ d d áː j n i k' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'n á j ʋ éː t͡ʃ j i' (predicted: 'ɔ ɔ n n n n i')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'ɔ ɔ n ɔ n n i t')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ m' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'ɔ r n n n i i')
# WARNING: Incorrect prediction:	'ʋ íː r' (predicted: 't éː s')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'p ɔ n n a t')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 'p ɔ t èː t i')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'ɔ ɔ n ɔ n n i i')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'b ɔ ɡ áː s t ʋ ɔ' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'ɔ ɔ n ɔ n n n n n i')
# WARNING: Incorrect prediction:	'x l àː t͡ʃ ɛ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'k j éː r' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'ɔ ɔ n ɔ n n n n i i')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'p ɔ t èː t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'p ɔ t èː t')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 'm èː t a')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'p ɔ n n a')
# WARNING: Incorrect prediction:	'p ɔ ɡ ɔ́ j' (predicted: 'p èː t ə s')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'ɔ ɔ n n n n i i')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'j àː ʋ ɔ r' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'b óː k' (predicted: 't éː s')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'k r ìː l ɔ' (predicted: 'p èː t ə t')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'ɔ r ɔ n n i t')
# WARNING: Incorrect prediction:	'b óː ʃ' (predicted: 't óː s')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm èː t ə t')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'ɔ r ɔ n n i t')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 'ɔ r n n n a')
# WARNING: Incorrect prediction:	'ɡ ɔ r ìː t͡s a' (predicted: 'p ɔ n n a t')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm éː t a')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɔ r n n n i')
# WER:	100.00
# PER:	90.40
# epoch: 2
# WARNING: Incorrect prediction:	'r ɔ m áː n' (predicted: 'r r áː n a')
# WARNING: Incorrect prediction:	'ʃ t ɛ ʋ ìː l ɔ' (predicted: 'ɔ l ɔ s t i t')
# WARNING: Incorrect prediction:	't íː p k a' (predicted: 'r áː n áː k')
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'r r r t t t a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'k r a n ìː n j a')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'k r a l áː n j i k')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 's t s t s t s t')
# WARNING: Incorrect prediction:	'n a p r áː ʋ a' (predicted: 'r r r áː n ə k')
# WARNING: Incorrect prediction:	's t á' (predicted: 's t s')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'ɔ ɔ ɔ s óː s')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 'p ɔ s ɔ s n ìː n a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's t s t s t')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'r r áː r')
# WARNING: Incorrect prediction:	't' (predicted: 't á')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'ɔ̀ː n óː k')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'r r r r j i')
# WARNING: Incorrect prediction:	'b óː d ɔ' (predicted: 'ɔ óː d ɔ')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'r r r áː t i k')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'r r a r r áː n j i k')
# WARNING: Incorrect prediction:	's p r ɛ m éː m b a' (predicted: 'p ɔ s ɔ s t s t i')
# WARNING: Incorrect prediction:	'i ɡ r àː t i' (predicted: 'r r r áː t i')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'r r r áː ʋ ə r')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'r r éː t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 's t s t t')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'r áː n a')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'p ɔ̀ː d ɔ̀ː n a')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p r éː t i')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'ɔ s t s t i')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'n óː n n n a')
# WARNING: Incorrect prediction:	'ʒ àː r a' (predicted: 'r r áː r')
# WARNING: Incorrect prediction:	's t ɔ́ ʋ' (predicted: 's t s t')
# WARNING: Incorrect prediction:	's l ɔ ʋ èː n ə t͡s' (predicted: 'p ɔ s t ìː s t i')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'p ɔ s óː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n á s')
# WARNING: Incorrect prediction:	'k r' (predicted: 'r éː t a')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'ɔ l ɔ s t ìː t i')
# WARNING: Incorrect prediction:	's í t' (predicted: 's t s')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'n a n a n j a')
# WARNING: Incorrect prediction:	'b r úː t ɔ' (predicted: 'p ɔ ʋ éː t')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'r r r r n n j a')
# WARNING: Incorrect prediction:	'd i j àː k' (predicted: 'z r n j a')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'p ɔ ɔ ɔ ɔ n ɔ ɔ')
# WARNING: Incorrect prediction:	'n á j b óː l j ɛ' (predicted: 'k ɔ l áː n ìː ʃ i')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'a l áː n a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'p r áː s t')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'p óː n n n a')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'p ɔ ɔ ɔ ʋ ɔ n ɔ k')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'n óː n a')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'r éː t r')
# WARNING: Incorrect prediction:	't ɛ̀ː t͡ʃ i' (predicted: 'r éː t a')
# WARNING: Incorrect prediction:	'm ɔ̀ː t͡ʃ i' (predicted: 'ɔ̀ː d óː k')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p óː d óː p')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'r r r r áː t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'r r áː t ə r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'ɔ̀ː n óː')
# WARNING: Incorrect prediction:	'ɔ d d áː j n i k' (predicted: 'p ɔ ɡ ɔ n n n a')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r r r r áː t i t')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r r r ə r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'p ɔ ʋ éː r')
# WARNING: Incorrect prediction:	'n á j ʋ éː t͡ʃ j i' (predicted: 'k l i j ìː ʃ i')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'i l i l áː n j i')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ m' (predicted: 'p ɔ̀ː d ɔ')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's t s t')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'p r r r ʋ ə r')
# WARNING: Incorrect prediction:	'ʋ íː r' (predicted: 'r éː r')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'z r r ʋ ə r')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'r r ə r')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'p r éː t a')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 'p r áː s ə r')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'p ɔ r ɔ ʋ éː t i')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'p ɔ̀ː d ɔ')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'r r r ə r')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'p ɔ̀ː s ə r')
# WARNING: Incorrect prediction:	'b ɔ ɡ áː s t ʋ ɔ' (predicted: 'ɔ ɔ ɔ ɔ s ɔ s ɔ')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'k ɔ s t i s t ìː n i k')
# WARNING: Incorrect prediction:	'x l àː t͡ʃ ɛ' (predicted: 'r r áː j ɛ')
# WARNING: Incorrect prediction:	'k j éː r' (predicted: 'r éː t a')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'k r a r i n ìː n i k')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'ɔ l éː t i')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'r r r éː t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'r r r r ə r')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's t éː t')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n óː n n j a')
# WARNING: Incorrect prediction:	'p ɔ ɡ ɔ́ j' (predicted: 'p óː d óː n')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'r r ɛ t r ɛ t i')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 's t s t')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'r l áː t i')
# WARNING: Incorrect prediction:	'j àː ʋ ɔ r' (predicted: 'r r éː t a')
# WARNING: Incorrect prediction:	'b óː k' (predicted: 'ɔ̀ː óː p')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'r éː t r')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'ɔ ɔ n óː n')
# WARNING: Incorrect prediction:	'k r ìː l ɔ' (predicted: 'r l áː t i')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r ɔ ʋ áː t i')
# WARNING: Incorrect prediction:	'b óː ʃ' (predicted: 'ɔ̀ː n óː')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 's t l t t')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ ɡ óː n n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 'ɔ l ɔ n ə t͡s')
# WARNING: Incorrect prediction:	'ɡ ɔ r ìː t͡s a' (predicted: 'p r r n ə n')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'l éː t a')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'p r r r áː t i')
# WER:	100.00
# PER:	82.37
# epoch: 3
# WARNING: Incorrect prediction:	'r ɔ m áː n' (predicted: 'r óː m n n')
# WARNING: Incorrect prediction:	'ʃ t ɛ ʋ ìː l ɔ' (predicted: 'n t ɛ ʋ íː l ɔ')
# WARNING: Incorrect prediction:	't íː p k a' (predicted: 't i p k a')
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p a r t ə a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l i m n ʃ i j')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'a n a t ɔ m i j a')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k á k ɔ b óː s t')
# WARNING: Incorrect prediction:	'n a p r áː ʋ a' (predicted: 'n á p r áː ʋ a')
# WARNING: Incorrect prediction:	's t á' (predicted: 's t a')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k óː n d ɔ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ ɡ ɛ l íː ʃ a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r ɛ b ə ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'i ʒ r a')
# WARNING: Incorrect prediction:	't' (predicted: 't íː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː d ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'n ɛ t͡ʃ áː àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k á t ɔ ɡ ɔ r i j a')
# WARNING: Incorrect prediction:	's p r ɛ m éː m b a' (predicted: 's p r r ɛ m b b a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː ʋ l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm s t t ɔ')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'd óː ʋ l l j')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p áː p ə t͡s')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'b a m b ə s')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'p i n s k i')
# WARNING: Incorrect prediction:	'ʒ àː r a' (predicted: 'ʒ áː r a')
# WARNING: Incorrect prediction:	's t ɔ́ ʋ' (predicted: 's t óː l')
# WARNING: Incorrect prediction:	's l ɔ ʋ èː n ə t͡s' (predicted: 's l ɔ ʋ ɛ n ə t͡s')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n íː t')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r íː ʃ')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n i t i t ə t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l i j a')
# WARNING: Incorrect prediction:	'b r úː t ɔ' (predicted: 'b r áː t ɔ')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i ʒ i n a')
# WARNING: Incorrect prediction:	'd i j àː k' (predicted: 'd i j a k')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l ɛ d áː l ɔ')
# WARNING: Incorrect prediction:	'n á j b óː l j ɛ' (predicted: 'n á j ɔ b l j ɛ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 't͡ʃ l íː ʃ a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b ɛ t n n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'p r a n ɔ b s k ɔ')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k óː n j')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p r ə r')
# WARNING: Incorrect prediction:	't ɛ̀ː t͡ʃ i' (predicted: 't íː ʃ i')
# WARNING: Incorrect prediction:	'm ɔ̀ː t͡ʃ i' (predicted: 'm óː ʃ i')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p óː m ə t͡s')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ʒ ɛ t͡ʃ i t͡ʃ t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j á n ʃ a r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n óː ʋ')
# WARNING: Incorrect prediction:	'ɔ d d áː j n i k' (predicted: 'ɔ d d áː n n i k')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r a z i m t t i')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r ùː d a r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z áː ʒ ɔ r')
# WARNING: Incorrect prediction:	'n á j ʋ éː t͡ʃ j i' (predicted: 'n á j ɛ ʋ j j i')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'l j ɛ s ɛ̀ː d n n')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's m k s')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'z ʋ ɛ d ə k')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'p r áː ʃ')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z a p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p ɔ d a j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n óː ʋ ɛ m b ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ k')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'd i r k a')
# WARNING: Incorrect prediction:	'b ɔ ɡ áː s t ʋ ɔ' (predicted: 'b óː ɡ a s t ə ɔ')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'm i s l l i n s k i i')
# WARNING: Incorrect prediction:	'x l àː t͡ʃ ɛ' (predicted: 't͡ʃ l áː ʃ ɛ')
# WARNING: Incorrect prediction:	'k j éː r' (predicted: 'k íː ə r')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a p a ɡ n i s t n n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l íː k ɔ')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'ʋ i d ə t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ i r áː j j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r ə ʋ')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'p ɔ ɡ ɔ́ j' (predicted: 'p óː ɡ óː j')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r áː s s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t i')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p óː d ɔ ɔ')
# WARNING: Incorrect prediction:	'k r ìː l ɔ' (predicted: 'k r íː l ɔ')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r i t s s k')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l t ɔ')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n óː ʃ i')
# WARNING: Incorrect prediction:	'ɡ ɔ r ìː t͡s a' (predicted: 'ɡ óː r i j a')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'n l ɛ d a t i')
# WER:	89.00
# PER:	31.24
# epoch: 4
# WARNING: Incorrect prediction:	'r ɔ m áː n' (predicted: 'r óː m a n')
# WARNING: Incorrect prediction:	'ʃ t ɛ ʋ ìː l ɔ' (predicted: 'ʃ t ɛ ʋ íː l ɔ')
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p àː r t m a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l u m i n i j')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'a n a t ɔ m j j a')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k a k ɔ ʋ ɔ s t')
# WARNING: Incorrect prediction:	'n a p r áː ʋ a' (predicted: 'n a p r àː ʋ a')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k ɔ n d ɔ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ d ɛ l i t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r èː b r ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'i ɡ r á')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k a t ɛ ɡ óː r i j a')
# WARNING: Incorrect prediction:	's p r ɛ m éː m b a' (predicted: 's p r ɛ m m m b a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː t͡s l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm éː s óː')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'd ɔ ʋ óː l')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p àː p ə t͡s')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'b àː m b u s')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n k i')
# WARNING: Incorrect prediction:	's l ɔ ʋ èː n ə t͡s' (predicted: 's l ɔ ʋ éː n ə t͡s')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n t t')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n ʃ t i ʃ ʃ t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l i j a')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i t͡s i n a')
# WARNING: Incorrect prediction:	'd i j àː k' (predicted: 'd ìː j a k')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l éː d a l ɔ')
# WARNING: Incorrect prediction:	'n á j b óː l j ɛ' (predicted: 'n a j b óː l j ɛ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'u l i t͡s a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b èː t ɔ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'f r a n n t͡s ɔ ɔ')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k óː n j')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p r éː t')
# WARNING: Incorrect prediction:	't ɛ̀ː t͡ʃ i' (predicted: 't èː t͡ʃ i')
# WARNING: Incorrect prediction:	'm ɔ̀ː t͡ʃ i' (predicted: 'm óː t͡ʃ i')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p ɔ m ɔ́ t͡ʃ')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j a n ʃ a r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n ʋ ʋ')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r a z áː m èː t i')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r úː d á r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	'n á j ʋ éː t͡ʃ j i' (predicted: 'n a j ʋ éː t͡ʃ j i')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's éː k')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z a p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p ɔ d a j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ èː m éː ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ p')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'd ìː r k a')
# WARNING: Incorrect prediction:	'b ɔ ɡ áː s t ʋ ɔ' (predicted: 'b ɔ ɡ àː s ʋ ʋ ɔ')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'm u s l i m àː s k i')
# WARNING: Incorrect prediction:	'x l àː t͡ʃ ɛ' (predicted: 'x l àː j ɛ')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a i ɡ a n i s a n n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l éː k')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'ʋ i d èː t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ i x r a j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r éː ɛ')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l')
# WARNING: Incorrect prediction:	'p ɔ ɡ ɔ́ j' (predicted: 'p ɔ ɡ óː j')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t i')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm àː r ɔ k')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'k r ìː l ɔ' (predicted: 'k r íː l ɔ')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r i t i s k')
# WARNING: Incorrect prediction:	'b óː ʃ' (predicted: 'b ʃ ʃ')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l ɔ')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n ɔ t͡ʃ i')
# WARNING: Incorrect prediction:	'ɡ ɔ r ìː t͡s a' (predicted: 'ɡ óː r i t͡s a')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm àː l')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɡ l éː d àː t i')
# WER:	80.00
# PER:	21.47
# epoch: 5
# WARNING: Incorrect prediction:	'r ɔ m áː n' (predicted: 'r ɔ̀ː m áː n')
# WARNING: Incorrect prediction:	'ʃ t ɛ ʋ ìː l ɔ' (predicted: 'ʃ t ɛ ʋ íː l ɔ')
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p a r t m a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l u m íː n i j')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k á k ɔ ʋ ɔ s t')
# WARNING: Incorrect prediction:	'n a p r áː ʋ a' (predicted: 'n á p r áː ʋ a')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k ɔ n d ɔ́ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ d ɛ l íː t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r èː b r ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'i ɡ r á')
# WARNING: Incorrect prediction:	't' (predicted: 't íː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k ɔ̀ː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k á t ɔ ɡ óː r i j a')
# WARNING: Incorrect prediction:	's p r ɛ m éː m b a' (predicted: 's p r ɛ m m b b a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː ɛ̀ː l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm ɛ s t ɔ')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'd ɔ ʋ ɔ̀ː l')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p àː p ə ʃ')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'b a m b u s')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n s k i')
# WARNING: Incorrect prediction:	'ʒ àː r a' (predicted: 'ʒ áː r a')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n íː t')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n ʃ t íː t ʃ t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l íː j a')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d íː t͡s i n a')
# WARNING: Incorrect prediction:	'd i j àː k' (predicted: 'd íː j áː k')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l ɛ d áː l ɔ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'u l ìː t͡s a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b èː t ɔ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'f r a n t͡s ɔ s k ɔ')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k ɔ̀ː n j')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p r éː t')
# WARNING: Incorrect prediction:	't ɛ̀ː t͡ʃ i' (predicted: 't èː t͡ʃ i')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p ɔ m ɔ́ t͡ʃ')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ʒ ʋ ɛ t͡ʃ ìː t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j á n ùː áː r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n óː ʋ')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r úː d áː r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	'n á j ʋ éː t͡ʃ j i' (predicted: 'n á j ʋ èː t͡ʃ j i')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'l j u b èː z ə n')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's èː k s')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'z ʋ èː z ə k')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'p r á x')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z a p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p ɔ d áː j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ èː b b ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ ʃ')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'd ìː r k a')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'ʋ ɔ̀ː s ə k')
# WARNING: Incorrect prediction:	'b ɔ ɡ áː s t ʋ ɔ' (predicted: 'b ɔ ɡ áː s ʋ ʋ ɔ')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'm u s l íː s n s k i')
# WARNING: Incorrect prediction:	'k j éː r' (predicted: 'k j èː r')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a p ɡ a n i s t a n')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'ʋ íː d èː t i')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r íː ɛ')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r j áː s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t i')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm a r k ɔ')
# WARNING: Incorrect prediction:	'j àː ʋ ɔ r' (predicted: 'j á ʋ ɔ r')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r íː t i s k')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l t ɔ')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n ɔ t͡ʃ i')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɡ l ɛ d àː t i')
# WER:	77.00
# PER:	19.90
# epoch: 6
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p áː r t m a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l ùː t͡ʃ ìː n i j')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'a n a t óː t͡ʃ i j a')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k a k ɔ ʋ óː s t')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k ɔ n d ɔ́ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ ɛ l ìː ìː t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r ɛ̀ː b r ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'ìː ɡ r a')
# WARNING: Incorrect prediction:	't' (predicted: 't óː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k a t ɔ ɡ óː t͡ʃ i j a')
# WARNING: Incorrect prediction:	's p r ɛ m éː m b a' (predicted: 's p r ɛ éː m m b a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː ɛ̀ː l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s s t')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm ɛ s t óː')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p a p éː ʃ')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'b a m b úː s')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n s k i')
# WARNING: Incorrect prediction:	'ʒ àː r a' (predicted: 'ʒ áː r a')
# WARNING: Incorrect prediction:	's l ɔ ʋ èː n ə t͡s' (predicted: 's l ɔ ɛ̀ː ɛ̀ː n ə t͡s')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n ʃ t íː t úː t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l i j a')
# WARNING: Incorrect prediction:	'b r úː t ɔ' (predicted: 'b r úː t óː')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i t͡s ìː n a')
# WARNING: Incorrect prediction:	'd i j àː k' (predicted: 'd i j áː k')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l d d a l ɔ')
# WARNING: Incorrect prediction:	'n á j b óː l j ɛ' (predicted: 'n a j b óː l j ɛ')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b ɛ t ɔ́ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'f r a n t͡s ɔ s k ɔ')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k óː n')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p r éː t')
# WARNING: Incorrect prediction:	'm ɔ̀ː t͡ʃ i' (predicted: 'm òː t͡ʃ i')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p ɔ m ɔ́ t͡ʃ')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ʒ ʋ ɛ t͡ʃ ìː t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j a n úː a r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n óː ʋ')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r úː d a r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	'n á j ʋ éː t͡ʃ j i' (predicted: 'n a j ʋ éː t͡ʃ j i')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'l j ùː b éː z ə n')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's ɛ̀ː k s')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'p r á x')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z a p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p òː d a j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ ɛ m b éː r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ p')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'd ìː r k a')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'ʋ òː s éː k')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'm u s i x áː n n s k i')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a i ɡ a n i s t a n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l ɛ k óː')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'ʋ i d èː t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ t͡ʃ éː r a j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r éː x')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r j áː s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t íː')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm a r k óː')
# WARNING: Incorrect prediction:	'j àː ʋ ɔ r' (predicted: 'j a ʋ óː r')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'k r ìː l ɔ' (predicted: 'k r ìː l óː')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r i t ìː s k')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm a l t óː')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n òː t͡ʃ i')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm a l óː')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɡ l ɛ d àː t i')
# WER:	76.00
# PER:	21.12
# epoch: 7
# WARNING: Incorrect prediction:	'r ɔ m áː n' (predicted: 'r ɔ̀ː m a n')
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p àː r t m a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l u m i n i j')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k á k ɔ ʋ ɔ s t')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k ɔ n d ɔ́ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ d ɛ l i t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r éː b r ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'i ɡ r á')
# WARNING: Incorrect prediction:	't' (predicted: 't íː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k a t ɛ ɡ óː r i j a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː ɛ̀ː l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm ɛ s t óː')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'd ɔ ʋ òː l')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p àː p ə t͡s')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'b a m b u s')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n s k i')
# WARNING: Incorrect prediction:	's l ɔ ʋ èː n ə t͡s' (predicted: 's l ɔ ʋ éː n ə t͡s')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n ʃ t íː t u t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l íː j a')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i t͡s ìː n a')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l éː d a l ɔ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'u l i t͡s a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b éː t ɔ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k óː n j')
# WARNING: Incorrect prediction:	't ɛ̀ː t͡ʃ i' (predicted: 't éː t͡ʃ i')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p ɔ m ɔ́ t͡ʃ')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ʒ ʋ ɛ t͡ʃ i t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j a n ùː a r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n óː ʋ')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r a z u m ɛ t i')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r úː d a r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'l j úː b éː z ə n')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z a p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p óː d a j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ éː m b ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ p')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'd ìː r k a')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'ʋ ɔ̀ː s ə k')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'm u s l íː m áː n s k i')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a f ɡ a n íː s t a n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l ɛ k óː')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ t͡ʃ éː r a j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r íː ɛ')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r j áː s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t i')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm a r k óː')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r i t i s k')
# WARNING: Incorrect prediction:	'b óː ʃ' (predicted: 'b ɔ́ ʃ')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l t óː')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n òː t͡ʃ i')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm àː l óː')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɡ l éː d a t i')
# WER:	67.00
# PER:	16.93
# epoch: 8
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p a r t m a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l u m i n i j')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'a n a t óː m i j a')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k a k ɔ ʋ óː s t')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k ɔ n d ɔ́ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ d ɛ l ìː t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r éː b r ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'i ɡ r á')
# WARNING: Incorrect prediction:	't' (predicted: 't óː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'b óː d ɔ' (predicted: 'b óː t óː')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k a t ɛ ɡ óː r i j a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː ɛ̀ː l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm ɛ s t óː')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'd ɔ ʋ ɔ́ l' (predicted: 'd ɔ ʋ òː l')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p àː p ə t͡s')
# WARNING: Incorrect prediction:	'b áː m b u s' (predicted: 'b a m b u s')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n s k i')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n íː t')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l íː j a')
# WARNING: Incorrect prediction:	'b r úː t ɔ' (predicted: 'b r úː t óː')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i t͡s ìː n a')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l ɛ d a l ɔ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'u l i t͡s a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b èː t ɔ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k óː n j')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p ə́ ɛ t')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p ɔ m ɔ t͡ʃ')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ʒ ʋ ɛ t͡ʃ ìː t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j a n ùː a r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n óː ʋ')
# WARNING: Incorrect prediction:	'ɔ d d áː j n i k' (predicted: 'ɔ d d a j n ìː k')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r a z u m ɛ t i')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r ùː d a r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's èː k s')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'z ʋ èː z ə k')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'p r á x')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z a p ɔ r')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ èː m b ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ p')
# WARNING: Incorrect prediction:	'd íː r k a' (predicted: 'd ìː r k a')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'ʋ ɔ̀ː s ə k')
# WARNING: Incorrect prediction:	'b ɔ ɡ áː s t ʋ ɔ' (predicted: 'b óː ɡ áː s t ʋ ɔ')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a p ɡ a n i s t áː n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l ɛ k óː')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ t͡ʃ éː r a j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r t͡s ɛ')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'p ɔ ɡ ɔ́ j' (predicted: 'p ɔ ɡ òː j')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r j áː s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t i')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm a r k óː')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r i t ìː s k')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l t óː')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n ɔ̀ː t͡ʃ i')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm a l óː')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɡ l ɛ d àː t i')
# WER:	70.00
# PER:	17.80
# epoch: 9
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p àː r t m a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l u m i n i j')
# WARNING: Incorrect prediction:	'a n a t ɔ m íː j a' (predicted: 'a n a t t m íː j a')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k á k ɔ ʋ ɔ s t')
# WARNING: Incorrect prediction:	's t á' (predicted: 's t áː')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ d ɛ l ìː t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r ɛ̀ː b r ɔ')
# WARNING: Incorrect prediction:	'íː ɡ r a' (predicted: 'i ɡ r á')
# WARNING: Incorrect prediction:	't' (predicted: 't áː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k á t ɛ ɡ óː r i j a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː j l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t á')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm ɛ̀ː s t ɔ')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p àː p ə ʃ')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n s k i')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n íː t')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n ʃ t íː t u t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l íː j a')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i i t͡s ìː n')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l éː d a l ɔ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'u l i t͡s a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b éː t ɔ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k óː n j')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p r éː t')
# WARNING: Incorrect prediction:	'ʒ ʋ èː t͡ʃ i t i' (predicted: 'ʒ ʋ ɛ t͡ʃ ìː t i')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j á n u a r')
# WARNING: Incorrect prediction:	'n ɔ́ ʋ' (predicted: 'n óː ʋ')
# WARNING: Incorrect prediction:	'ɔ d d áː j n i k' (predicted: 'ɔ t d áː j n i k')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r a z u m ɛ t i')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	'l j u b éː z ə n' (predicted: 'l j úː b éː z ə n')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's ɛ̀ː k s')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'z ʋ èː z ə k')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'p r á x')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z á p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p ɔ d àː j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ èː m b ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ p')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'ʋ ɔ̀ː s ə k')
# WARNING: Incorrect prediction:	'm u s l i m áː n s k i' (predicted: 'm u s l i m áː n k k i')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a p ɡ a n i s t a n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l ɛ k óː')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'ʋ i d èː t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ t͡ʃ éː r a j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r íː x')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r j áː s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t íː')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm a r k óː')
# WARNING: Incorrect prediction:	'j àː ʋ ɔ r' (predicted: 'j á ʋ ɔ r')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'p r i t íː s k' (predicted: 'p r i t ìː s k')
# WARNING: Incorrect prediction:	'b óː ʃ' (predicted: 'b ɔ́ ʃ')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l t ɔ')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n ɔ t͡ʃ i')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm a l óː')
# WARNING: Incorrect prediction:	'ɡ l èː d a t i' (predicted: 'ɡ l ɛ d àː t i')
# WER:	68.00
# PER:	17.98
# epoch: 10
# WARNING: Incorrect prediction:	'a p a r t m áː' (predicted: 'a p áː r t t a')
# WARNING: Incorrect prediction:	'a l u m ìː n i j' (predicted: 'a l u m i n i j')
# WARNING: Incorrect prediction:	'k a k ɔ̀ː ʋ ɔ s t' (predicted: 'k á k ɔ b óː s t')
# WARNING: Incorrect prediction:	'k ɔ n d óː m' (predicted: 'k ɔ n d ɔ m')
# WARNING: Incorrect prediction:	's k ɔ d éː l i t͡s a' (predicted: 's k ɔ d èː l i t͡s a')
# WARNING: Incorrect prediction:	's r ɛ b r óː' (predicted: 's r èː b r ɔ')
# WARNING: Incorrect prediction:	't' (predicted: 't áː')
# WARNING: Incorrect prediction:	'k òː ʒ a' (predicted: 'k óː ʒ a')
# WARNING: Incorrect prediction:	'p r àː z ə n' (predicted: 'p r áː z ə n')
# WARNING: Incorrect prediction:	'u ʒ ìː ʋ a t i' (predicted: 'u ʒ i ʋ àː t i')
# WARNING: Incorrect prediction:	'k a t ɛ ɡ ɔ r íː j a' (predicted: 'k a t ɛ ɡ óː r i j a')
# WARNING: Incorrect prediction:	'm íː x a ɛ l a' (predicted: 'm i x áː ɛ̀ː l a')
# WARNING: Incorrect prediction:	'ʋ ə̀ r s t a' (predicted: 'ʋ r s t a')
# WARNING: Incorrect prediction:	'm èː s t ɔ' (predicted: 'm ɛ̀ː s t ɔ')
# WARNING: Incorrect prediction:	'ʋ íː l a' (predicted: 'ʋ ìː l a')
# WARNING: Incorrect prediction:	'p áː p ɛ ʃ' (predicted: 'p áː p ə ɔ')
# WARNING: Incorrect prediction:	'f íː n s k i' (predicted: 'f i n s k i')
# WARNING: Incorrect prediction:	'ʒ àː r a' (predicted: 'ʒ áː r a')
# WARNING: Incorrect prediction:	'ɔ ɡ l á s' (predicted: 'ɔ ɡ l áː s')
# WARNING: Incorrect prediction:	'n í t' (predicted: 'n íː t')
# WARNING: Incorrect prediction:	'k r' (predicted: 'k r úː x')
# WARNING: Incorrect prediction:	'i n ʃ t i t úː t' (predicted: 'i n ʃ t íː t u t')
# WARNING: Incorrect prediction:	's í t' (predicted: 's íː t')
# WARNING: Incorrect prediction:	'áː n ɡ l i j a' (predicted: 'a n ɡ l íː j a')
# WARNING: Incorrect prediction:	'm ɛ d i t͡s íː n a' (predicted: 'm ɛ d i t͡s ìː n a')
# WARNING: Incorrect prediction:	'ɔ ɡ l ɛ d àː l ɔ' (predicted: 'ɔ ɡ l ɛ d áː l ɔ')
# WARNING: Incorrect prediction:	'ùː l i t͡s a' (predicted: 'u l i t͡s a')
# WARNING: Incorrect prediction:	'b ɛ t óː n' (predicted: 'b èː t ɔ n')
# WARNING: Incorrect prediction:	'b ɔ ʋ n ìː k' (predicted: 'b óː l n i k')
# WARNING: Incorrect prediction:	'f r a n t͡s óː s k ɔ' (predicted: 'f r a n t͡s èː n k ɔ')
# WARNING: Incorrect prediction:	'k ɔ́ n' (predicted: 'k ɔ́ n j')
# WARNING: Incorrect prediction:	'p r ɛ t' (predicted: 'p ə́ ɛ t')
# WARNING: Incorrect prediction:	'm ɔ̀ː t͡ʃ i' (predicted: 'm òː t͡ʃ i')
# WARNING: Incorrect prediction:	'p ɔ m óː t͡ʃ' (predicted: 'p ɔ m ɔ t͡ʃ')
# WARNING: Incorrect prediction:	'j áː n u a r' (predicted: 'j á n u a r')
# WARNING: Incorrect prediction:	'r a z u m èː t i' (predicted: 'r a z u m ɛ t i')
# WARNING: Incorrect prediction:	'r u d àː r' (predicted: 'r u d a r')
# WARNING: Incorrect prediction:	'z a x ɔ́ t' (predicted: 'z a x óː t')
# WARNING: Incorrect prediction:	's éː k s' (predicted: 's èː k s')
# WARNING: Incorrect prediction:	'd èː l a ʋ ə t͡s' (predicted: 'd ɛ l áː ʋ ə t͡s')
# WARNING: Incorrect prediction:	'z ʋ éː z ə k' (predicted: 'z ʋ èː z ə k')
# WARNING: Incorrect prediction:	'p r áː x' (predicted: 'p ə́ áː x')
# WARNING: Incorrect prediction:	'z a p ɔ́ r' (predicted: 'z á p ɔ r')
# WARNING: Incorrect prediction:	's p ɔ̀ː d a j' (predicted: 's p ɔ d a j')
# WARNING: Incorrect prediction:	'n ɔ ʋ ɛ̀ː m b ə r' (predicted: 'n ɔ ʋ èː m b ə r')
# WARNING: Incorrect prediction:	'ɡ r ɔ́ f' (predicted: 'ɡ r ɔ́ p')
# WARNING: Incorrect prediction:	'ʋ óː s ə k' (predicted: 'ʋ ɔ̀ː s ə k')
# WARNING: Incorrect prediction:	'k j éː r' (predicted: 'k j èː r')
# WARNING: Incorrect prediction:	'a ʋ ɡ áː n i s t a n' (predicted: 'a p ɡ a n i s t áː n')
# WARNING: Incorrect prediction:	'm l èː k ɔ' (predicted: 'm l ɛ k óː')
# WARNING: Incorrect prediction:	'ʋ ìː d ɛ t i' (predicted: 'ʋ i d èː t i')
# WARNING: Incorrect prediction:	'ʋ t͡ʃ èː r a j' (predicted: 'ʋ t͡ʃ éː r a j')
# WARNING: Incorrect prediction:	's ə r t͡s éː' (predicted: 's r íː ɛ')
# WARNING: Incorrect prediction:	'n i k óː l i' (predicted: 'n i k ɔ l i')
# WARNING: Incorrect prediction:	'm ɛ r j àː s ə t͡s' (predicted: 'm ɛ r j áː s ə t͡s')
# WARNING: Incorrect prediction:	'íː s t i' (predicted: 'i s t íː')
# WARNING: Incorrect prediction:	'm àː r k ɔ' (predicted: 'm a r k óː')
# WARNING: Incorrect prediction:	'ʋ ə́ r s t' (predicted: 'ʋ r s t')
# WARNING: Incorrect prediction:	'p ɔ̀ː z n ɔ' (predicted: 'p ɔ z n ɔ')
# WARNING: Incorrect prediction:	'b óː ʃ' (predicted: 'b ɔ́ ʃ')
# WARNING: Incorrect prediction:	'm áː l t ɔ' (predicted: 'm àː l t ɔ')
# WARNING: Incorrect prediction:	'p ɔ d ɡ àː n a' (predicted: 'p ɔ d ɡ áː n a')
# WARNING: Incorrect prediction:	's i n óː t͡ʃ i' (predicted: 's i n ɔ t͡ʃ i')
# WARNING: Incorrect prediction:	'm àː l ɔ' (predicted: 'm a l óː')
# WER:	64.00
# PER:	16.23

# %% [markdown]
# ## Prediction

# %%
checkpoint = torch.load(root_path+f"models/slv/10.pt")
model.load_state_dict(checkpoint['state_dict'])
_, translated = inference(model, test_iter, SRC, TRG, True, 64)

# %%
def generate_final_prediction(test_file_path, translated, output_file_path):
  '''
  test_file_path -- the file path to the test file
  translated -- a list of lists that contain predictions
  output_file_path -- output file path that you will create
  '''
  with open(test_file_path, "r", encoding="utf-8") as f:
    gold = f.read().splitlines()
  processed_translated = []
  for word in translated:
    curr_word = []
    for char in word:
      if char == "<eow>":
        break
      if char != "<eow>" and char != "<pad>":
        curr_word.append(char)
    processed_translated.append(curr_word)
  with open(output_file_path, "w", encoding="utf-8") as fout:
    for g, t in zip(gold, processed_translated):
      fout.write(g + "\t" + " ".join(t) + "\n")

# %%
slv_test_path = data_path + "slv_test.tsv"

# %%
generate_final_prediction(slv_test_path, translated, root_path+"predictions/slv_preds.tsv")
